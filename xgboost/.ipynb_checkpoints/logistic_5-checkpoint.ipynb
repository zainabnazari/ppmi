# %%
#to install R :
#conda install -c r r-irkernel
# to install a library from R
#!pip install library edgeR

# %%
#we just do it once
#!pip3 install xgboost

# %%
# a pachage that might need for some normalisation later on.
#!pip install rnanorm;
#import rnanorm

# %%
#this package has many of the normalisation procedures.
#!pip install bioinfokit
#!pip install bioinfokit --upgrade

# %%
#!pip install conorm
from bioinfokit.analys import norm, get_data
import bioinfokit
import conorm # for tmm normalisation

# %%
from xgboost import XGBClassifier
import numpy as np
import pandas as pd
from pathlib import Path
import functools
# sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
#loading the counts data

path1=Path("/home/znazari/machine_learning_ppmi")

quant_rna1=pd.read_csv(path1/"ordered_bl_matrix_ir2_count.txt", header=None,index_col=[0] )
quant_rna=quant_rna1.rename(columns=quant_rna1.iloc[0]).drop(quant_rna1.index[0]).reset_index(drop=True)

# %%
#great idea to set the geneid as an index counter so to avoid its confliction with the rest.
dff1 = quant_rna.set_index('Geneid')

# %% [markdown]
# In below we do the following steps:
#
# 1- we filter the rows in which their average is less than 5.
#
# 2- we apply tmm normalisation
#
# 3- we take log2 of the data

# %%
#finding average of each row, and making a new column for the average
i_average=dff1.mean(axis=1)
i_average
dff1["average"]=i_average

# %%
#we filter all the rows that their average is less than 5,then we drop the nan value rows
filter = dff1["average"]>5
# filtering data
dff1.where(filter, inplace = True)
dff_drop1=dff1.dropna()
dff_drop1
# Out:
#                    10874   12499  12593  13039   13424  14281  14331  14426  \
# Geneid
# ENSG00000223972.4   10.0    10.0   12.0    7.0    10.0    5.0    7.0    4.0
# ENSG00000227232.4  192.0   418.0  276.0  252.0   292.0  235.0  162.0  209.0
# ENSG00000238009.2   38.0    67.0   93.0   33.0    54.0   33.0   43.0   47.0
# ENSG00000237683.5   28.0    82.0   38.0   31.0   125.0  155.0   44.0   38.0
# ENSG00000239906.1    5.0    26.0   13.0   16.0    15.0   23.0    4.0    1.0
# ...                  ...     ...    ...    ...     ...    ...    ...    ...
# ENSG00000198695.2  346.0   142.0  169.0  158.0   138.0  241.0   65.0   83.0
# ENSG00000210194.1   48.0    17.0   28.0   24.0    24.0   54.0    3.0    7.0
# ENSG00000198727.2  766.0  1506.0  405.0  379.0  1316.0  581.0  501.0  328.0
# ENSG00000210195.2   62.0    54.0   16.0   67.0   130.0   60.0   63.0   72.0
# ENSG00000210196.2  169.0   133.0   65.0  221.0   275.0   95.0  178.0  174.0
#
#                    15761  16580  ...  41381   4139  60002  60015   60024  \
# Geneid                           ...
# ENSG00000223972.4    4.0    4.0  ...    7.0    4.0    9.0    9.0     8.0
# ENSG00000227232.4  128.0   99.0  ...  260.0  216.0  158.0  205.0   210.0
# ENSG00000238009.2   16.0   48.0  ...   39.0   32.0  113.0   61.0   131.0
# ENSG00000237683.5   25.0   31.0  ...   70.0   50.0   65.0   80.0   210.0
# ENSG00000239906.1    4.0    6.0  ...    8.0    3.0    3.0   12.0    11.0
# ...                  ...    ...  ...    ...    ...    ...    ...     ...
# ENSG00000198695.2  493.0   69.0  ...  205.0  102.0  136.0   69.0    86.0
# ENSG00000210194.1   85.0   10.0  ...   29.0    9.0   25.0   10.0    16.0
# ENSG00000198727.2  517.0  192.0  ...  583.0  339.0  461.0  498.0  1049.0
# ENSG00000210195.2   62.0  105.0  ...   11.0   45.0   25.0   48.0    56.0
# ENSG00000210196.2  198.0  112.0  ...   31.0  114.0   87.0   89.0   204.0
#
#                     60036  60095  60171   85242     average
# Geneid
# ENSG00000223972.4    11.0    2.0    1.0     6.0    5.366337
# ENSG00000227232.4   512.0  211.0  134.0   432.0  228.336634
# ENSG00000238009.2   102.0   57.0    6.0   141.0   53.974540
# ENSG00000237683.5   307.0   43.0   12.0  1171.0   97.002829
# ENSG00000239906.1    27.0    5.0    3.0    29.0    8.961810
# ...                   ...    ...    ...     ...         ...
# ENSG00000198695.2   132.0   59.0  142.0    92.0  188.437058
# ENSG00000210194.1    13.0   12.0   13.0     4.0   27.509194
# ENSG00000198727.2  1260.0  494.0  402.0  2501.0  699.930693
# ENSG00000210195.2    73.0   34.0   54.0    26.0   54.833098
# ENSG00000210196.2   212.0   68.0  103.0    62.0  144.961810
#
# [26528 rows x 708 columns]

# %%
dff_drop=dff_drop1.drop("average",axis='columns')

# %%
dff_drop
# Out:
#                    10874   12499  12593  13039   13424  14281  14331  14426  \
# Geneid
# ENSG00000223972.4   10.0    10.0   12.0    7.0    10.0    5.0    7.0    4.0
# ENSG00000227232.4  192.0   418.0  276.0  252.0   292.0  235.0  162.0  209.0
# ENSG00000238009.2   38.0    67.0   93.0   33.0    54.0   33.0   43.0   47.0
# ENSG00000237683.5   28.0    82.0   38.0   31.0   125.0  155.0   44.0   38.0
# ENSG00000239906.1    5.0    26.0   13.0   16.0    15.0   23.0    4.0    1.0
# ...                  ...     ...    ...    ...     ...    ...    ...    ...
# ENSG00000198695.2  346.0   142.0  169.0  158.0   138.0  241.0   65.0   83.0
# ENSG00000210194.1   48.0    17.0   28.0   24.0    24.0   54.0    3.0    7.0
# ENSG00000198727.2  766.0  1506.0  405.0  379.0  1316.0  581.0  501.0  328.0
# ENSG00000210195.2   62.0    54.0   16.0   67.0   130.0   60.0   63.0   72.0
# ENSG00000210196.2  169.0   133.0   65.0  221.0   275.0   95.0  178.0  174.0
#
#                    15761  16580  ...   4136   41381  4139   60002  60015  \
# Geneid                           ...
# ENSG00000223972.4    4.0    4.0  ...    23.0    7.0    4.0    9.0    9.0
# ENSG00000227232.4  128.0   99.0  ...   273.0  260.0  216.0  158.0  205.0
# ENSG00000238009.2   16.0   48.0  ...    97.0   39.0   32.0  113.0   61.0
# ENSG00000237683.5   25.0   31.0  ...   363.0   70.0   50.0   65.0   80.0
# ENSG00000239906.1    4.0    6.0  ...    35.0    8.0    3.0    3.0   12.0
# ...                  ...    ...  ...     ...    ...    ...    ...    ...
# ENSG00000198695.2  493.0   69.0  ...   236.0  205.0  102.0  136.0   69.0
# ENSG00000210194.1   85.0   10.0  ...    33.0   29.0    9.0   25.0   10.0
# ENSG00000198727.2  517.0  192.0  ...  1026.0  583.0  339.0  461.0  498.0
# ENSG00000210195.2   62.0  105.0  ...    64.0   11.0   45.0   25.0   48.0
# ENSG00000210196.2  198.0  112.0  ...   144.0   31.0  114.0   87.0   89.0
#
#                     60024   60036  60095  60171   85242
# Geneid
# ENSG00000210195.2  5.779936  6.260892  6.345875  5.825372  7.402486  ...
# ENSG00000210196.2  6.434161  7.744708  7.607262  7.484717  7.494745  ...
#
#                       4136      41381     4139      60002     60015  \
# Geneid
# ENSG00000223972.4  4.215646  2.770891  2.471216  3.350007  3.486518
# ENSG00000227232.4  7.728716  7.798797  7.910839  7.340961  7.851091
# ENSG00000238009.2  6.245394  5.092819  5.193682  6.860969  6.118787
# ENSG00000237683.5  8.138478  5.920638  5.821713  6.072473  6.504440
# ENSG00000239906.1  4.800609  2.940816  2.149288  2.028079  3.865030
# ...                     ...       ...       ...       ...       ...
# ENSG00000198695.2  7.519427  7.457391  6.835789  7.126111  6.293873
# ENSG00000210194.1  4.718147  4.677781  3.471216  4.728518  3.624022
# ENSG00000198727.2  9.634904  8.960715  8.558679  8.879828  9.127486
# ENSG00000210195.2  5.653052  3.355853  5.672850  4.728518  5.779300
# ENSG00000210196.2  6.810593  4.770891  6.994778  6.487510  6.656443
#
#                        60024      60036     60095     60171      85242
# Geneid
# ENSG00000223972.4   3.377687   3.654023  1.698075  1.549102   2.665104
# ENSG00000227232.4   7.928861   9.071875  7.841033  7.625917   8.615973
# ENSG00000238009.2   7.252156   6.755561  5.971093  3.356457   7.007496
# ENSG00000237683.5   7.928861   8.335847  5.572544  4.249541  10.052506
# ENSG00000239906.1   3.792724   4.876415  2.698075  2.549102   4.764640
# ...                      ...        ...       ...       ...        ...
# ENSG00000198695.2   6.650705   7.124343  6.020003  7.708973   6.396908
# ENSG00000210194.1   4.295224   3.876415  3.813552  4.356457   2.179677
# ENSG00000198727.2  10.243935  10.369413  9.064397  9.203738  11.146615
# ENSG00000210195.2   6.040652   6.278514  5.242395  6.330461   4.612637
# ENSG00000210196.2   7.887242   7.803770  6.221637  7.249541   5.835029
#
# [26528 rows x 707 columns]

# %%
#the first step to get the cpm norm is these two lines
#nm = norm()
#nm.cpm(df=dff)
#here is the cpm norm taking step 
#cpm_df = nm.cpm_norm
#cpm_df.head(5)

# %%
#loading the quant diagnosis: prediction

quant_predict1=pd.read_csv(path1/"the_diagnosis_count_ir2.txt", header=None ,index_col=[0])
quant_predict=quant_predict1.rename(columns=quant_predict1.iloc[0]).drop(quant_predict1.index[0]).reset_index(drop=True)

# %%
#transposed matrix
t_quant=data_log_tmm.T
t_quant
# Out:
# Geneid  ENSG00000223972.4  ENSG00000227232.4  ENSG00000238009.2  \
# 10874            3.434337           7.567363           5.260308
# 12499            3.377868           8.629243           6.005899
# 12593            3.098459           7.511762           5.952609
# 13039            3.368313           8.351307           5.455776
# 13424            3.290525           8.025850           5.612453
# ...                   ...                ...                ...
# 60024            3.377687           7.928861           7.252156
# 60036            3.654023           9.071875           6.755561
# 60095            1.698075           7.841033           5.971093
# 60171            1.549102           7.625917           3.356457
# 85242            2.665104           8.615973           7.007496
#
# Geneid  ENSG00000237683.5  ENSG00000239906.1  ENSG00000241860.2  \
# 10874            4.832886           2.559868           6.820396
# 12499            6.293476           4.673324           8.037378
# 12593            4.683422           3.205375           6.921582
# 13039            5.368313           4.455776           7.412707
# 13424            6.808373           3.831093           7.814087
# ...                   ...                ...                ...
# 60024            7.928861           3.792724           8.460427
# 60036            8.335847           4.876415           8.340523
# 60095            5.572544           2.698075           7.293021
# 60171            4.249541           2.549102           5.834504
# 85242           10.052506           4.764640           8.508801
#
# Geneid  ENSG00000222623.1  ENSG00000228463.4  ENSG00000230021.3  \
# 10874            3.144830           5.260308           3.144830
# 12499            5.673324           7.386042           2.918437
# 12593            4.304910           6.881835           2.719948
# 13039            4.275204           7.672094           4.455776
# 13424            5.445803           6.864516           3.831093
# ...                   ...                ...                ...
# 60024            5.880187           7.675367           4.600079
# 60036            4.069060           7.238985           4.528492
# 60095            4.200575           7.854579           2.435040
# 60171            2.871030           5.249541           3.356457
# 85242            3.317181           7.450206           2.857749
#
# Geneid  ENSG00000225630.1  ...  ENSG00000198938.2  ENSG00000198840.2  \
# 10874            5.062368  ...          12.790489          10.190438
# 12499            4.962831  ...          13.075310           9.975074
# 12593            2.857451  ...          10.983452           7.582895
# 13039            4.175668  ...          11.749315           9.169213
# 13424            4.153021  ...          12.238361           9.118805
# ...                   ...  ...                ...                ...
# 60024            5.161958  ...          12.996888          10.123641
# 60036            5.238985  ...          13.142867          10.036287
# 60095            3.435040  ...          11.584279           8.806599
# 60171            4.455992  ...          12.155507           9.403970
# 85242            5.715730  ...          11.206477           7.981871
#
# Geneid  ENSG00000212907.2  ENSG00000198886.2  ENSG00000198786.2  \
# 10874            8.567363           9.907120           8.974905
# 12499            8.449818          10.542318           9.495865
# 12593            5.328757           7.967875           7.274537
# 13039            7.487254           9.152948           8.169213
# 13424            8.679716          10.390470           9.808373
# ...                   ...                ...                ...
# 60024            8.465149          10.474548           9.246681
# 60036            9.057745          10.823948           9.798681
# 60095            6.971093           9.023005           8.221637
# 60171            7.688653           9.440885           8.317286
# 85242            9.642384          10.943886          10.702455
#
# Geneid  ENSG00000198695.2  ENSG00000210194.1  ENSG00000198727.2  \
# 10874            8.413697           5.589615           9.557988
# 12499            7.078308           4.088362          10.475900
# 12593            6.807411           4.256001           8.063356
# 13039            7.681196           5.012169           8.938169
# 13424            6.950034           4.474949          10.194133
# ...                   ...                ...                ...
# 60024            6.650705           4.295224          10.243935
# 60036            7.124343           3.876415          10.369413
# 60095            6.020003           3.813552           9.064397
# 60171            7.708973           4.356457           9.203738
# 85242            6.396908           2.179677          11.146615
#
# Geneid  ENSG00000210195.2  ENSG00000210196.2
# 10874            5.952185           7.384296
# 12499            5.699796           6.984526
# 12593            3.485483           5.442414
# 13039            6.455776           8.162729
# 13424            6.864516           7.939618
# ...                   ...                ...
# 60024            6.040652           7.887242
# 60036            6.278514           7.803770
# 60095            5.242395           6.221637
# 60171            6.330461           7.249541
# 85242            4.612637           5.835029
#
# [707 rows x 26528 columns]

# %%
searchfor = ['Healthy Control', "Parkinson's Disease"]

# %%
#we just pick those that are either health control or parkinson'd diseases
quant_p=quant_predict[quant_predict['COHORT_DEFINITION'].astype(str).str.contains('|'.join(searchfor))]

# %%
quant_new_predict=quant_p['BL_PATNO']

# %%
r_quant_patients=[int(x) for x in quant_new_predict]

# %%
#here we select those rna-seq data that includes both health control and parkinson 
selected_quant_rna=data_log_tmm[r_quant_patients]

# %%
select_quant_rna=selected_quant_rna.T

# %%
quant_p['COHORT_DEFINITION'].replace(['Healthy Control', "Parkinson's Disease"],
                        [0, 1], inplace=True)
# Out:
# /tmp/ipykernel_26269/93247712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quant_p['COHORT_DEFINITION'].replace(['Healthy Control', "Parkinson's Disease"],

# %%
#here we make the model
bst_q = XGBClassifier(n_estimators=100, max_depth=30, learning_rate=0.2, objective='reg:logistic')

# %%
# %%time
#here we repeat the machine learning procedure for k times

k=5
g0=[]
p0=[]
for i in range(k):
    X_trainq, X_testq, y_trainq, y_testq = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
    logr=bst_q.fit(X_trainq, y_trainq)
    accuracy = accuracy_score(y_testq, logr.predict(X_testq))
    roc_score = roc_auc_score(y_testq,logr.predict(X_testq))
    g= (accuracy * 100.0)
    p= (roc_score*100.0)
    g0+=[g]
    p0+=[p]
aa1=round(sum(g0)/k)
aa2=round(sum(p0)/k)
aa3=round(np.std(g0))
aa4=round(np.std(p0))
print("average accuracy:",aa1)
print("average roc_auc score:",aa2)
print("accuracy std:",aa3)
print("auc_roc score std:",aa4)
# Out:
# average accuracy: 65
# average roc_auc score: 50
# accuracy std: 2
# auc_roc score std: 2
# CPU times: user 18min 39s, sys: 26.9 s, total: 19min 6s
# Wall time: 9min 56s

# %%
from sklearn.ensemble import GradientBoostingClassifier
model_gb = GradientBoostingClassifier()

# %%
# %%time
#here we repeat the machine learning procedure for k times

k_gb=5
g0_gb=[]
p0_gb=[]
for i in range(k_gb):
    X_train_gb, X_test_gb, y_train_gb, y_test_gb = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
    m_gb=model_gb.fit(X_trainq, y_trainq)
    accuracy_gb = accuracy_score(y_test_gb, m_gb.predict(X_test_gb))
    roc_score_gb = roc_auc_score(y_test_gb,m_gb.predict(X_test_gb))
    g_gb= (accuracy_gb * 100.0)
    p_gb= (roc_score_gb*100.0)
    g0_gb+=[g_gb]
    p0_gb+=[p_gb]
gb1=round(sum(g0_gb)/k_gb)
gb2=round(sum(p0_gb)/k_gb)
gb3=round(np.std(g0_gb))
gb4=round(np.std(p0_gb))
print("average accuracy:",gb1)
print("average roc_auc score:",gb2)
print("accuracy std:",gb3)
print("auc_roc score std:",gb4)
# Out:
# average accuracy: 89
# average roc_auc score: 85
# accuracy std: 2
# auc_roc score std: 2
# CPU times: user 26min 44s, sys: 5.02 s, total: 26min 49s
# Wall time: 26min 52s

# %%
p0_gb
# Out:
# [89.23500434656621,
#  82.70879424778761,
#  82.88461538461537,
#  85.70741758241759,
#  83.68838763575606]

# %%
g0_gb
# Out:
# [92.65536723163842,
#  87.00564971751412,
#  87.57062146892656,
#  89.26553672316385,
#  88.13559322033898]

# %%
p0
# Out:
# [49.27405973451327,
#  49.7536945812808,
#  52.24703222159411,
#  51.24897624897624,
#  44.96923076923077]

# %%
g0
# Out:
# [59.887005649717516,
#  62.14689265536724,
#  64.40677966101694,
#  61.5819209039548,
#  58.75706214689266]

# %%
fl=[]
for i in range(5):
    fl+=[i]
print("ki:",fl)
# Out:
# ki: [0, 1, 2, 3, 4]

# %%
# Out:
# 314.68926553672316

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_recall_curve

import matplotlib.pyplot as plt

# %%
print('Accuracy:  ', accuracy_score(y_testq,bst_q.predict(X_testq)))
print('Precision: ', precision_score(y_testq,bst_q.predict(X_testq)))
print('Recall:    ', recall_score(y_testq,bst_q.predict(X_testq)))
print('F1:        ', f1_score(y_testq,bst_q.predict(X_testq)))
print('ROC-AUC:   ', roc_auc_score(y_testq,bst_q.predict(X_testq)))
print('\nConfusion Matrix\n{0}'.format(confusion_matrix(y_testq,bst_q.predict(X_testq))))
# Out:
# Accuracy:   0.5819209039548022
# Precision:  0.30952380952380953
# Recall:     0.22413793103448276
# F1:         0.26
# ROC-AUC:    0.490220226021443
#
# Confusion Matrix
# [[90 29]
#  [45 13]]

# %%
print('Accuracy:  ', accuracy_score(y_trainq,bst_q.predict(X_trainq)))
print('Precision: ', precision_score(y_trainq,bst_q.predict(X_trainq)))
print('Recall:    ', recall_score(y_trainq,bst_q.predict(X_trainq)))
print('F1:        ', f1_score(y_trainq,bst_q.predict(X_trainq)))
print('ROC-AUC:   ', roc_auc_score(y_trainq,bst_q.predict(X_trainq)))
print('\nConfusion Matrix\n{0}'.format(confusion_matrix(y_trainq,bst_q.predict(X_trainq))))
# Out:
# Accuracy:   0.9683698296836983
# Precision:  1.0
# Recall:     0.8934426229508197
# F1:         0.9437229437229437
# ROC-AUC:    0.9467213114754098
#
# Confusion Matrix
# [[289   0]
#  [ 13 109]]

# %% [markdown]
# *confusion matrix* TN, FP; FN, TP

# %%
roc = roc_curve(y_testq,bst_q.predict_proba(X_testq)[:,1])
pr  = precision_recall_curve(y_testq,bst_q.predict_proba(X_testq)[:,1])

f = plt.figure(figsize=(20,7))
ax = f.add_subplot(121)
ax.plot(roc[0],roc[1])
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('False Positive Rate')
ax.set_title('ROC Curve')
ax.grid(which='both')
ax = f.add_subplot(122)
ax.plot(pr[1],pr[0])
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
ax.set_title('PR-curve')
ax.grid(which='both')
plt.show()

# %%
roc = roc_curve(y_trainq,bst_q.predict_proba(X_trainq)[:,1])
pr  = precision_recall_curve(y_trainq,bst_q.predict_proba(X_trainq)[:,1])

f = plt.figure(figsize=(20,7))
ax = f.add_subplot(121)
ax.plot(roc[0],roc[1])
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('False Positive Rate')
ax.set_title('ROC Curve')
ax.grid(which='both')
ax = f.add_subplot(122)
ax.plot(pr[1],pr[0])
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
ax.set_title('PR-curve')
ax.grid(which='both')
plt.show()

# %%
roc = roc_curve(y_train_gb,m_gb.predict_proba(X_train_gb)[:,1])
pr  = precision_recall_curve(y_train_gb,m_gb.predict_proba(X_train_gb)[:,1])

f = plt.figure(figsize=(20,7))
ax = f.add_subplot(121)
ax.plot(roc[0],roc[1])
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('False Positive Rate')
ax.set_title('ROC Curve')
ax.grid(which='both')
ax = f.add_subplot(122)
ax.plot(pr[1],pr[0])
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
ax.set_title('PR-curve')
ax.grid(which='both')
plt.show()
