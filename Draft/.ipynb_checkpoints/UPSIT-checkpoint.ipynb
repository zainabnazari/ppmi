# %% [markdown]
# # UPSIT
# University of Pennsylvania Smell Identification Test

# %%
import dask.dataframe as dd
import pandas as pd
import numpy as np
import os
import glob
import functools
from pathlib import Path
import time
from datetime import datetime

# %%
path=Path("/scratch/znazari/PPMI_ver_sep2022/study_data/Non-motor_Assessments/")

# %%
upsit=pd.read_csv(path/"University_of_Pennsylvania_Smell_Identification_Test__UPSIT_.csv")
upsit
# Out:
#                                    REC_ID   PATNO EVENT_ID  PAG_NAME   INFODT  \
# 0    d81f5db4-e053-43dd-a231-2f8bee5d4a77   40568      V06     UPSIT  04/2021
# 1    a2e5cf26-3492-408b-a415-7ebb512d82ec   52927      V06     UPSIT  08/2021
# 2    70405222-b13e-4b3d-9a0e-45736c0cfd1a   54446      V06     UPSIT  01/2021
# 3    9604fa0f-7784-4e83-86f8-4815b4d14c02   73940      V06     UPSIT  08/2021
# 4    45603e0f-6354-4593-a9ca-bef9a722e2b9   74004      V06     UPSIT  04/2021
# ..                                    ...     ...      ...       ...      ...
# 405  13cb7395-7cee-4d75-a118-72fc6b9602fd  160040       BL     UPSIT  07/2022
# 406  cb9a5d5a-ad2b-47ca-98b4-8270e64d5d92  160231       BL     UPSIT  07/2022
# 407  c76808d8-1b2f-4de1-8356-6667e7af8efb  161236       BL     UPSIT  07/2022
# 408  1d0f1329-480c-4a52-bcde-b0c8a7bfbe92  162140       SC  UPSITPRO  06/2022
# 409  85668207-63cd-40c4-bbd6-30641413de46  162929       BL     UPSIT  08/2022
#
#      SCENT_01_CORRECT  SCENT_01_RESPONSE  SCENT_02_CORRECT  SCENT_02_RESPONSE  \
# 0                   0                  1                 1                  2
# 1                   1                  2                 1                  2
# 2                   1                  2                 1                  2
# 3                   0                  4                 1                  2
# 4                   0                  4                 0                  1
# ..                ...                ...               ...                ...
# 405                 1                  2                 1                  2
# 406                 0                  1                 0                  1
# 407                 0                  4                 1                  2
# 408                 1                  2                 1                  2
# 409                 0                  3                 0                  3
#
#      SCENT_03_CORRECT  ...  SCENT_39_RESPONSE  SCENT_40_CORRECT  \
# 0                   1  ...                2.0               1.0
# 1                   1  ...                2.0               1.0
# 2                   1  ...                2.0               1.0
# 3                   1  ...                2.0               1.0
# 4                   1  ...                2.0               1.0
# ..                ...  ...                ...               ...
# 405                 0  ...                4.0               1.0
# 406                 1  ...                3.0               1.0
# 407                 0  ...                2.0               1.0
# 408                 1  ...                2.0               1.0
# 409                 0  ...                4.0               0.0
#
#      SCENT_40_RESPONSE  TOTAL_CORRECT  UPSITFORM  UPSIT_PRCNTGE  \
# 0                  1.0           33.0        NaN           21.0
# 1                  1.0           40.0        2.0           75.5
# 2                  1.0           33.0        NaN           21.0
# 3                  1.0            NaN        2.0            NaN
# 4                  1.0           30.0        NaN           41.0
# ..                 ...            ...        ...            ...
# 405                1.0           27.0        1.0           16.5
# 406                1.0           21.0        2.0            4.0
# 407                1.0           26.0        1.0            9.0
# 408                1.0           31.0        2.0           17.5
# 409                3.0           12.0        1.0            4.5
#
#      UPSIT_PRCTVER   UPSIT_SOURCE  ORIG_ENTRY  LAST_UPDATE
# 0          12/2020  Clinical Site     01/2022   2022-01-17
# 1          12/2020  Clinical Site     08/2021   2021-08-25
# 2          12/2020  Clinical Site     04/2021   2021-04-30
# 3          12/2020  Clinical Site     12/2021   2021-12-03
# 4          12/2020  Clinical Site     05/2021   2021-05-20
# ..             ...            ...         ...          ...
# 405        12/2020  Clinical Site     08/2022   2022-08-04
# 406        12/2020  Clinical Site     08/2022   2022-08-09
# 407        12/2020  Clinical Site     08/2022   2022-08-11
# 408        12/2020  Clinical Site     08/2022   2022-08-15
# 409        12/2020  Clinical Site     08/2022   2022-08-19
#
# [410 rows x 92 columns]

# %%
# Select rows where 'EVENT_ID' is 'BL'
upsit_bl = upsit[upsit['EVENT_ID'] == 'BL']
upsit_bl
# Out:
#                                    REC_ID   PATNO EVENT_ID PAG_NAME   INFODT  \
# 11   7a1c5e26-4585-43fc-98ed-d7f7c1f96615  100001       BL    UPSIT  10/2020
# 12   0ba58cab-3f09-4602-a53a-f89ea25bb7b7  100005       BL    UPSIT  01/2021
# 13   99f0ae5f-9b46-467d-a3ac-40c1d64c6079  100006       BL    UPSIT  12/2020
# 14   f90e3f42-584d-4d69-b35e-3f5891d15e26  100012       BL    UPSIT  03/2021
# 15   7988c9cc-98af-40d0-bd38-cc0b4df7a31c  100017       BL    UPSIT  12/2020
# ..                                    ...     ...      ...      ...      ...
# 404  ebffafe2-a734-4b47-a6e7-02b1e078ff99  158359       BL    UPSIT  07/2022
# 405  13cb7395-7cee-4d75-a118-72fc6b9602fd  160040       BL    UPSIT  07/2022
# 406  cb9a5d5a-ad2b-47ca-98b4-8270e64d5d92  160231       BL    UPSIT  07/2022
# 407  c76808d8-1b2f-4de1-8356-6667e7af8efb  161236       BL    UPSIT  07/2022
# 409  85668207-63cd-40c4-bbd6-30641413de46  162929       BL    UPSIT  08/2022
#
#      SCENT_01_CORRECT  SCENT_01_RESPONSE  SCENT_02_CORRECT  SCENT_02_RESPONSE  \
# 11                  0                  4                 0                  3
# 12                  0                  3                 1                  2
# 13                  0                  1                 1                  2
# 14                  0                  3                 1                  2
# 15                  1                  2                 0                  3
# ..                ...                ...               ...                ...
# 404                 0                  4                 1                  2
# 405                 1                  2                 1                  2
# 406                 0                  1                 0                  1
# 407                 0                  4                 1                  2
# 409                 0                  3                 0                  3
#
#      SCENT_03_CORRECT  ...  SCENT_39_RESPONSE  SCENT_40_CORRECT  \
# 11                  1  ...                2.0               1.0
# 12                  1  ...                2.0               1.0
# 13                  1  ...                1.0               1.0
# 14                  1  ...                2.0               1.0
# 15                  1  ...                2.0               1.0
# ..                ...  ...                ...               ...
# 404                 0  ...                4.0               1.0
# 405                 0  ...                4.0               1.0
# 406                 1  ...                3.0               1.0
# 407                 0  ...                2.0               1.0
# 409                 0  ...                4.0               0.0
#
#      SCENT_40_RESPONSE  TOTAL_CORRECT  UPSITFORM  UPSIT_PRCNTGE  \
# 11                 1.0           26.0        NaN           17.5
# 12                 1.0           34.0        NaN           38.0
# 13                 1.0           23.0        NaN            2.0
# 14                 1.0           29.0        NaN           18.5
# 15                 1.0           30.0        NaN            7.5
# ..                 ...            ...        ...            ...
# 404                1.0           22.0        1.0            3.0
# 405                1.0           27.0        1.0           16.5
# 406                1.0           21.0        2.0            4.0
# 407                1.0           26.0        1.0            9.0
# 409                3.0           12.0        1.0            4.5
#
#      UPSIT_PRCTVER   UPSIT_SOURCE  ORIG_ENTRY  LAST_UPDATE
# 11         12/2020  Clinical Site     10/2020   2020-10-15
# 12         12/2020  Clinical Site     02/2021   2021-02-25
# 13         12/2020  Clinical Site     01/2021   2021-01-07
# 14         12/2020  Clinical Site     03/2021   2021-03-26
# 15         12/2020  Clinical Site     01/2021   2021-01-05
# ..             ...            ...         ...          ...
# 404        12/2020  Clinical Site     08/2022   2022-08-04
# 405        12/2020  Clinical Site     08/2022   2022-08-04
# 406        12/2020  Clinical Site     08/2022   2022-08-09
# 407        12/2020  Clinical Site     08/2022   2022-08-11
# 409        12/2020  Clinical Site     08/2022   2022-08-19
#
# [273 rows x 92 columns]

# %%
upsit["TOTAL_CORRECT"]
# Out:
# 0      33.0
# 1      40.0
# 2      33.0
# 3       NaN
# 4      30.0
#        ...
# 405    27.0
# 406    21.0
# 407    26.0
# 408    31.0
# 409    12.0
# Name: TOTAL_CORRECT, Length: 410, dtype: float64

# %%
path2=Path("/scratch/znazari/PPMI_ver_sep2022/study_data/Archived_PPMI_Data")

# %%
upsit2=pd.read_csv(path2/"University_of_Pennsylvania_Smell_ID_Test-Archived.csv")
upsit2
# Out:
#          REC_ID F_STATUS  PATNO EVENT_ID PAG_NAME   INFODT  UPSITBK1  \
# 0     272459601        S   3000       BL    UPSIT  02/2011       9.0
# 1     743784701        S   3000      V15    UPSIT  03/2019       9.0
# 2     278749401        S   3001       BL    UPSIT  03/2011       4.0
# 3     735836701        S   3001      V15    UPSIT  03/2019       3.0
# 4     281560401        S   3002       BL    UPSIT  03/2011       3.0
# ...         ...      ...    ...      ...      ...      ...       ...
# 2656  755546201        S  91097      V12    UPSIT  07/2019       5.0
# 2657  491673901        S  92490       BL    UPSIT  01/2015       3.0
# 2658  505245401        S  92834       BL    UPSIT  02/2015       2.0
# 2659  675170901        S  92834      V08    UPSIT  01/2018       1.0
# 2660  769738801        S  92834      V12    UPSIT  03/2020       3.0
#
#       UPSITBK2  UPSITBK3  UPSITBK4 NORMATIVE_SCORE  UPSITFORM ORIG_ENTRY  \
# 0         10.0       6.0      10.0       Normosmia          1    02/2011
# 1          8.0       9.0       9.0       Normosmia          1    06/2019
# 2          6.0       9.0       6.0        Hyposmia          1    03/2011
# 3          4.0       6.0       4.0         Anosmia          1    04/2019
# 4          5.0       3.0       6.0         Anosmia          1    03/2011
# ...        ...       ...       ...             ...        ...        ...
# 2656       3.0       5.0       5.0         Anosmia          1    09/2019
# 2657       1.0       3.0       3.0         Anosmia          1    01/2015
# 2658       3.0       5.0       2.0         Anosmia          1    02/2015
# 2659       4.0       4.0       5.0         Anosmia          1    02/2018
# 2660       4.0       2.0       5.0         Anosmia          1    03/2020
#
#                 LAST_UPDATE  QUERY SITE_APRV
# 0     2020-06-25 16:02:19.0    NaN   03/2011
# 1     2020-06-25 16:02:25.0    NaN   06/2019
# 2     2020-06-25 16:04:31.0    NaN   03/2011
# 3     2020-06-25 16:04:37.0    NaN   04/2019
# 4     2020-04-01 17:33:42.0    NaN   03/2011
# ...                     ...    ...       ...
# 2656  2020-06-29 10:24:10.0    NaN   09/2019
# 2657  2020-06-30 12:44:17.0    NaN   01/2015
# 2658  2020-06-26 16:46:36.0    NaN   02/2015
# 2659  2020-06-26 16:47:08.0    NaN   02/2018
# 2660  2020-06-26 16:47:29.0    NaN   03/2020
#
# [2661 rows x 16 columns]
