# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path2 = Path("/home/znazari/data")# where the output data will be saved at the end.
path3 = Path("/home/znazari/ppmi_files/External_data")

# %%
x_data = pd.read_csv(path3/"AdaBoost_params_all_top_models_summary - Foglio2-1.csv")
x1_data = x_data.iloc[30:35]
x2_data = x1_data.iloc[:, 1:]
x2_data.set_index('Unnamed: 1', inplace=True)
x2_data.index.name = 'Accuracy'
x12_data = x2_data.astype(float).round(2)
x12_data
# Out:
#             20    26    35    47    63    84   111   148   197   263  526  \
# Accuracy
# MAX       0.80  0.85  0.84  0.85  0.84  0.84  0.85  0.83  0.85  0.80  NaN
# Mean+SD   0.76  0.80  0.80  0.82  0.82  0.82  0.81  0.80  0.80  0.77  NaN
# Mean      0.73  0.77  0.78  0.79  0.79  0.79  0.78  0.77  0.76  0.75  NaN
# Mean-SD   0.70  0.73  0.75  0.76  0.76  0.76  0.75  0.74  0.73  0.72  NaN
# MIN       0.67  0.70  0.72  0.73  0.71  0.71  0.67  0.70  0.68  0.69  NaN
#
#           1052  2204
# Accuracy
# MAX        NaN   NaN
# Mean+SD    NaN   NaN
# Mean       NaN   NaN
# Mean-SD    NaN   NaN
# MIN        NaN   NaN

# %%
x_data
# Out:
#         Unnamed: 0 Unnamed: 1            20            26            35  \
# 0   Transciptomics        NaN      Accuracy      Accuracy      Accuracy
# 1              NaN        MAX          0.75  0.7804878049  0.8109756098
# 2              NaN    Mean+SD  0.6944968388  0.7252820195  0.7508586548
# 3              NaN       Mean  0.6630644772   0.691922241  0.7233759961
# 4              NaN    Mean-SD  0.6316321156  0.6585624625  0.6958933374
# 5              NaN        MIN  0.5853658537  0.6097560976  0.6707317073
# 6              NaN        NaN           AUC           AUC           AUC
# 7              NaN        MAX  0.7481234362  0.7994588572    0.85891748
# 8              NaN    Mean+SD  0.7109393764  0.7522567665  0.8010998029
# 9              NaN       Mean  0.6773797291  0.7167216312  0.7726891239
# 10             NaN    Mean-SD  0.6438200817  0.6811864959  0.7442784449
# 11             NaN        MIN  0.5699473058   0.612446959  0.7088867805
# 12             NaN        NaN   Sensitivity   Sensitivity   Sensitivity
# 13             NaN        MAX  0.5957446809  0.6078431373  0.7142857143
# 14             NaN    Mean+SD   0.442969397   0.493980212  0.5595454908
# 15             NaN       Mean  0.3760225282  0.4264384867  0.4928435368
# 16             NaN    Mean-SD  0.3090756594  0.3588967613  0.4261415828
# 17             NaN        MIN  0.2222222222  0.2131147541  0.3275862069
# 18             NaN        NaN   Specificity   Specificity   Specificity
# 19             NaN        MAX  0.9411764706  0.9245283019  0.9270833333
# 20             NaN    Mean+SD  0.8632199298   0.875553477  0.8798842983
# 21             NaN       Mean  0.8163896065  0.8339009659  0.8440868129
# 22             NaN    Mean-SD  0.7695592831  0.7922484548  0.8082893274
# 23             NaN        MIN  0.6936936937  0.7407407407  0.7410714286
# 24             NaN        NaN           NaN           NaN           NaN
# 25             NaN        NaN           NaN           NaN           NaN
# 26      Proteomics        NaN           NaN           NaN           NaN
# 27             NaN        NaN           NaN           NaN           NaN
# 28             NaN        NaN            24            32            42
# 29             NaN        NaN      Accuracy      Accuracy      Accuracy
# 30             NaN        MAX  0.8023952096  0.8502994012  0.8383233533
# 31             NaN    Mean+SD   0.762807873  0.7982109681  0.8043218045
# 32             NaN       Mean  0.7325546926  0.7661113417  0.7770795044
# 33             NaN    Mean-SD  0.7023015122  0.7340117152  0.7498372042
# 34             NaN        MIN  0.6706586826  0.7005988024  0.7245508982
# 35             NaN        NaN           AUC           AUC           AUC
# 36             NaN        MAX  0.8393939394  0.8824833703  0.8879280526
# 37             NaN    Mean+SD  0.7914736463  0.8255498616  0.8415093898
# 38             NaN       Mean  0.7589325841  0.7950448244  0.8146085313
# 39             NaN    Mean-SD  0.7263915219  0.7645397871  0.7877076728
# 40             NaN        MIN   0.681372549  0.7261682243  0.7366765972
# 41             NaN        NaN   Sensitivity   Sensitivity   Sensitivity
# 42             NaN        MAX  0.6363636364          0.68  0.7222222222
# 43             NaN    Mean+SD  0.5552636954  0.5966739337  0.5967953737
# 44             NaN       Mean  0.4863920129  0.5311793616   0.533169938
# 45             NaN    Mean-SD  0.4175203304  0.4656847895  0.4695445024
# 46             NaN        MIN   0.275862069  0.3442622951  0.3928571429
# 47             NaN        NaN   Specificity   Specificity   Specificity
# 48             NaN        MAX  0.9333333333   0.963963964   0.962962963
# 49             NaN    Mean+SD   0.889643551  0.9174975578  0.9296217696
# 50             NaN       Mean  0.8560398699  0.8835688533  0.8990641237
# 51             NaN    Mean-SD  0.8224361888  0.8496401488  0.8685064779
# 52             NaN        MIN  0.7631578947  0.7837837838  0.8260869565
#
#               47            63            84           111           148  \
# 0       Accuracy      Accuracy      Accuracy      Accuracy      Accuracy
# 1   0.8109756098  0.8292682927  0.8780487805  0.8719512195  0.8719512195
# 2   0.7780306979  0.7936057091  0.8128085109  0.8202057869  0.8170694547
# 3   0.7497585124  0.7668437575  0.7840328985  0.7858609032  0.7846406288
# 4   0.7214863269   0.740081806  0.7552572861  0.7515160195  0.7522118029
# 5   0.6829268293  0.7134146341  0.6951219512  0.6951219512  0.6829268293
# 6            AUC           AUC           AUC           AUC           AUC
# 7   0.8727595386  0.8913690476  0.9081651209  0.9227391021  0.9260942761
# 8   0.8322090566  0.8636036098   0.877203063  0.8861460161  0.8806550361
# 9    0.803887085  0.8384744049  0.8512509038  0.8545631934  0.8518823547
# 10  0.7755651135  0.8133451999  0.8252987447  0.8229803707  0.8231096733
# 11  0.7166406386  0.7646464646    0.77996633  0.7823682498  0.7703703704
# 12   Sensitivity   Sensitivity   Sensitivity   Sensitivity   Sensitivity
# 13          0.72  0.7307692308  0.8113207547  0.7068965517  0.7659574468
# 14  0.6065930891  0.6167592669  0.6333487338  0.6207707337  0.6220900315
sp1_data = sp_data.iloc[:, 1:]
sp1_data.set_index('Unnamed: 1', inplace=True)
sp1_data.index.name = 'Specificity'
sp12_data=sp1_data.astype(float).round(2)
sp12_data
# Out:
#                20    26    35    47    63    84   111   148   197   263  526  \
# Specificity
# MAX          0.93  0.96  0.96  0.97  0.97  0.97  0.98  0.96  0.97  0.96  NaN
# Mean+SD      0.89  0.92  0.93  0.93  0.94  0.93  0.94  0.93  0.93  0.92  NaN
# Mean         0.86  0.88  0.90  0.90  0.90  0.90  0.91  0.90  0.90  0.89  NaN
# Mean-SD      0.82  0.85  0.87  0.88  0.87  0.87  0.88  0.87  0.87  0.86  NaN
#
#              1052  2204
# Specificity
# MAX           NaN   NaN
# Mean+SD       NaN   NaN
# Mean          NaN   NaN
# Mean-SD       NaN   NaN

# %%
auc_data = x_data.iloc[36:41]
auc2_data = auc_data.iloc[:, 1:]
auc2_data.set_index('Unnamed: 1', inplace=True)
auc2_data.index.name = 'AUC'
auc12_data=auc2_data.astype(float).round(2)
auc12_data
# Out:
#            20    26    35    47    63    84   111   148   197   263  526  \
# AUC
# MAX      0.84  0.88  0.89  0.91  0.91  0.91  0.92  0.88  0.90  0.85  NaN
# Mean+SD  0.79  0.83  0.84  0.86  0.87  0.86  0.87  0.85  0.84  0.81  NaN
# Mean     0.76  0.80  0.81  0.84  0.84  0.83  0.83  0.82  0.81  0.78  NaN
# Mean-SD  0.73  0.76  0.79  0.81  0.82  0.80  0.80  0.79  0.78  0.74  NaN
# MIN      0.68  0.73  0.74  0.77  0.77  0.75  0.72  0.73  0.71  0.69  NaN
#
#          1052  2204
# AUC
# MAX       NaN   NaN
# Mean+SD   NaN   NaN
# Mean      NaN   NaN
# Mean-SD   NaN   NaN
# MIN       NaN   NaN

# %%
s_data = x_data.iloc[42:47]
s1_data = s_data.iloc[:, 1:]
s1_data.set_index('Unnamed: 1', inplace=True)
s1_data.index.name = 'Sensitivity'
s12_data=s1_data.astype(float).round(2)
s12_data
# Out:
#                20    26    35    47    63    84   111   148   197   263  526  \
# Sensitivity
# MAX          0.64  0.68  0.72  0.69  0.73  0.70  0.76  0.64  0.63  0.60  NaN
# Mean+SD      0.56  0.60  0.60  0.62  0.63  0.61  0.60  0.57  0.55  0.51  NaN
# Mean         0.49  0.53  0.53  0.55  0.56  0.55  0.52  0.51  0.49  0.46  NaN
# Mean-SD      0.42  0.47  0.47  0.49  0.49  0.49  0.45  0.44  0.43  0.40  NaN
# MIN          0.28  0.34  0.39  0.39  0.41  0.37  0.36  0.35  0.34  0.31  NaN
#
#              1052  2204
# Sensitivity
# MAX           NaN   NaN
# Mean+SD       NaN   NaN
# Mean          NaN   NaN
# Mean-SD       NaN   NaN
# MIN           NaN   NaN

# %%
df = x12_data

# Transpose the DataFrame
df_transposed = df.transpose()

# Define color palette
palette = sns.color_palette("flare", as_cmap=True)

# Create a line plot with markers for each statistic
plt.figure(figsize=(7, 5))

for i, column in enumerate(df_transposed.columns):
    color = palette((4-i) / len(df_transposed.columns))
    sns.lineplot(data=df_transposed, x=df_transposed.index, y=column, marker='o', label=column, color=color)

# Fill color between Mean-SD and Mean+SD
plt.fill_between(df_transposed.index, df_transposed['Mean-SD'], df_transposed['Mean+SD'], color='slateblue', alpha=0.3)

plt.xlabel('Num. Genes',  fontsize=17)
plt.ylabel('Values')
plt.title('Accuracy',  fontsize=17)
plt.grid(True)
plt.ylim(0, 1)
plt.yticks([i/20 for i in range(21)])
plt.legend(fontsize=11)
plt.show( )

# %%
df = auc12_data

# Transpose the DataFrame
df_transposed = df.transpose()

# Define color palette
palette = sns.color_palette("flare", as_cmap=True)

# Create a line plot with markers for each statistic
plt.figure(figsize=(7, 5))

for i, column in enumerate(df_transposed.columns):
    color = palette((4-i) / len(df_transposed.columns))
    sns.lineplot(data=df_transposed, x=df_transposed.index, y=column, marker='o', label=column, color=color)

# Fill color between Mean-SD and Mean+SD
plt.fill_between(df_transposed.index, df_transposed['Mean-SD'], df_transposed['Mean+SD'], color='slateblue', alpha=0.3)

plt.xlabel('Num. Genes',fontsize=17)
plt.ylabel('Values')
plt.title('AUC',  fontsize=17)
plt.grid(True)
plt.ylim(0, 1)
plt.yticks([i/20 for i in range(21)])
plt.legend(fontsize=11)
plt.show()

# %%
df = s12_data

# Transpose the DataFrame
df_transposed = df.transpose()

# Define color palette
palette = sns.color_palette("flare", as_cmap=True)

# Create a line plot with markers for each statistic
plt.figure(figsize=(7, 5))

for i, column in enumerate(df_transposed.columns):
    color = palette((4-i) / len(df_transposed.columns))
    sns.lineplot(data=df_transposed, x=df_transposed.index, y=column, marker='o', label=column, color=color)

# Fill color between Mean-SD and Mean+SD
plt.fill_between(df_transposed.index, df_transposed['Mean-SD'], df_transposed['Mean+SD'], color='slateblue', alpha=0.3)

plt.xlabel('Num. Genes',fontsize=17)
plt.ylabel('Values')
plt.title('Sensitivity', fontsize=17)
plt.grid(True)
plt.ylim(0, 1)
plt.yticks([i/20 for i in range(21)])
plt.legend(fontsize=11)
plt.show()

# %%
df = sp12_data

# Transpose the DataFrame
df_transposed = df.transpose()

# Define color palette
palette = sns.color_palette("flare", as_cmap=True)

# Create a line plot with markers for each statistic
plt.figure(figsize=(7, 5))

for i, column in enumerate(df_transposed.columns):
    color = palette((4-i) / len(df_transposed.columns))
    sns.lineplot(data=df_transposed, x=df_transposed.index, y=column, marker='o', label=column, color=color)

# Fill color between Mean-SD and Mean+SD
plt.fill_between(df_transposed.index, df_transposed['Mean-SD'], df_transposed['Mean+SD'], color='slateblue', alpha=0.3)

plt.xlabel('Num. Genes',fontsize=17)
plt.ylabel('Values')
plt.title('Specificity',fontsize=17)
plt.grid(True)
plt.ylim(0, 1)
plt.yticks([i/20 for i in range(21)])
plt.legend(fontsize=11)
plt.show()
