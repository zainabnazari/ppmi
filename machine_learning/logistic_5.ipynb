# %%
#to install R :
#conda install -c r r-irkernel
# to install a library from R
#!pip install library edgeR

# %%
#we just do it once
#!pip3 install xgboost

# %%
# a pachage that might need for some normalisation later on.
#!pip install rnanorm;
#import rnanorm

# %%
#this package has many of the normalisation procedures.
#!pip install bioinfokit
#!pip install bioinfokit --upgrade

# %%
#!pip install conorm
from bioinfokit.analys import norm, get_data
import bioinfokit
import conorm # for tmm normalisation

# %%
from xgboost import XGBClassifier
import numpy as np
import pandas as pd
from pathlib import Path
import functools
# sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_recall_curve

import matplotlib.pyplot as plt

from sklearn.ensemble import GradientBoostingClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.utils import class_weight
from sklearn.feature_selection import SelectFromModel

# %%
#loading the counts data

path1=Path("/home/znazari/machine_learning_ppmi")

quant_rna1=pd.read_csv(path1/"p_ordered_bl_matrix_ir2_count.txt", header=None,index_col=[0] )
quant_rna=quant_rna1.rename(columns=quant_rna1.iloc[0]).drop(quant_rna1.index[0]).reset_index(drop=True)

# %%
#great idea to set the geneid as an index counter so to avoid its confliction with the rest.
dff1 = quant_rna.set_index('Geneid')

# %%
dff1
# Out:
#                  10874  12499  12593  13039  13424  14281  14331  14426  \
# Geneid
# ENSG00000186092      0      0      3      0      0      0      0      0
# ENSG00000187634     19      1     59      4      5     61      2      1
# ENSG00000188976    384    649    529    347    440    383    302    324
# ENSG00000187961    115    158    164     80    171    119     99    133
# ENSG00000187583     24     21     45     12     16     33      8      5
# ...                ...    ...    ...    ...    ...    ...    ...    ...
# ENSG00000212907    385    369     60    138    460    138    173    144
# ENSG00000198886    976   1577    379    440   1508    627    534    406
# ENSG00000198786    511    763    234    222   1007    429    203    186
# ENSG00000198695    346    142    169    158    138    241     65     83
# ENSG00000198727    766   1506    405    379   1316    581    501    328
#
#                  15761  16580  ...  4136   41381  4139   60002  60015  60024  \
# Geneid                         ...
# ENSG00000186092      0      0  ...      0      0      0      0      0      0
# ENSG00000187634     44      3  ...     43      8     16     29      1      1
# ENSG00000188976    336    234  ...    775    369    321    292    344    342
# ENSG00000187961    122     44  ...    275    121    101    106    109    105
# ENSG00000187583     47     11  ...     71     12     32     27     13      7
# ...                ...    ...  ...    ...    ...    ...    ...    ...    ...
# ENSG00000212907    151     31  ...    379    257    102    148    176    305
# ENSG00000198886    603    168  ...   1403    652    333    546    669   1231
# ENSG00000198786    428     83  ...    689    479    230    237    311    525
# ENSG00000198695    493     69  ...    236    205    102    136     69     86
# ENSG00000198727    517    192  ...   1026    583    339    461    498   1049
#
#                  60036  60095  60171  85242
# Geneid
# ENSG00000186092      0      0      0      0
# ENSG00000187634      3      0      1      1
# ENSG00000188976    858    280    161   1082
# ENSG00000187961    205     85     71    310
# ENSG00000187583     14      8      6     26
# ...                ...    ...    ...    ...
# ENSG00000212907    507    115    140    881
# ENSG00000198886   1727    480    474   2173
# ENSG00000198786    848    275    217   1838
# ENSG00000198695    132     59    142     92
# ENSG00000198727   1260    494    402   2501
#
# [18735 rows x 707 columns]

# %% [raw]
# path_i=Path("/home/znazari/ppmi_files/xgboost")
#
# protein_ivan=pd.read_csv(path_i/"protein_coding_genes_EnsembleIDs_12mag2023.txt",sep='\t')
# protein_ivan

# %% [markdown]
# In below we do the following steps:
#
# 1- we filter the rows in which their average is less than 5.
#
# 2- we apply tmm normalisation
#
# 3- we take log2 of the data

# %%
#finding average of each row, and making a new column for the average
i_average=dff1.mean(axis=1)
i_average
dff1["average"]=i_average

# %%
#we filter all the rows that their average is less than 5,then we drop the nan value rows
filter = dff1["average"]>5
# filtering data
dff1.where(filter, inplace = True)
dff_drop1=dff1.dropna()
dff_drop1
# Out:
#                  10874   12499  12593  13039   13424  14281  14331  14426  \
# Geneid
# ENSG00000187634   19.0     1.0   59.0    4.0     5.0   61.0    2.0    1.0
# ENSG00000188976  384.0   649.0  529.0  347.0   440.0  383.0  302.0  324.0
# ENSG00000187961  115.0   158.0  164.0   80.0   171.0  119.0   99.0  133.0
# ENSG00000187583   24.0    21.0   45.0   12.0    16.0   33.0    8.0    5.0
# ENSG00000187642   25.0     5.0   42.0    5.0     3.0   18.0    2.0    2.0
# ...                ...     ...    ...    ...     ...    ...    ...    ...
# ENSG00000212907  385.0   369.0   60.0  138.0   460.0  138.0  173.0  144.0
# ENSG00000198886  976.0  1577.0  379.0  440.0  1508.0  627.0  534.0  406.0
# ENSG00000198786  511.0   763.0  234.0  222.0  1007.0  429.0  203.0  186.0
# ENSG00000198695  346.0   142.0  169.0  158.0   138.0  241.0   65.0   83.0
# ENSG00000198727  766.0  1506.0  405.0  379.0  1316.0  581.0  501.0  328.0
#
#                  15761  16580  ...  41381   4139  60002  60015   60024  \
# Geneid                         ...
# ENSG00000187634   44.0    3.0  ...    8.0   16.0   29.0    1.0     1.0
# ENSG00000188976  336.0  234.0  ...  369.0  321.0  292.0  344.0   342.0
# ENSG00000187961  122.0   44.0  ...  121.0  101.0  106.0  109.0   105.0
# ENSG00000187583   47.0   11.0  ...   12.0   32.0   27.0   13.0     7.0
# ENSG00000187642   26.0    1.0  ...    2.0   25.0   33.0    1.0     3.0
# ...                ...    ...  ...    ...    ...    ...    ...     ...
# ENSG00000212907  151.0   31.0  ...  257.0  102.0  148.0  176.0   305.0
# ENSG00000198886  603.0  168.0  ...  652.0  333.0  546.0  669.0  1231.0
# ENSG00000198786  428.0   83.0  ...  479.0  230.0  237.0  311.0   525.0
# ENSG00000198695  493.0   69.0  ...  205.0  102.0  136.0   69.0    86.0
# ENSG00000198727  517.0  192.0  ...  583.0  339.0  461.0  498.0  1049.0
#
#                   60036  60095  60171   85242     average
# Geneid
# ENSG00000187634     3.0    0.0    1.0     1.0   14.421499
# ENSG00000188976   858.0  280.0  161.0  1082.0  412.256011
# ENSG00000187961   205.0   85.0   71.0   310.0  127.451202
# ENSG00000187583    14.0    8.0    6.0    26.0   20.200849
# ENSG00000187642     3.0    1.0    1.0     2.0   10.516266
# ...                 ...    ...    ...     ...         ...
# ENSG00000212907   507.0  115.0  140.0   881.0  216.925035
# ENSG00000198886  1727.0  480.0  474.0  2173.0  771.575672
# ENSG00000198786   848.0  275.0  217.0  1838.0  458.526167
# ENSG00000198695   132.0   59.0  142.0    92.0  188.437058
# ENSG00000198727  1260.0  494.0  402.0  2501.0  699.930693
#
# [16299 rows x 708 columns]

# %%
dff_drop=dff_drop1.drop("average",axis='columns')

# %%
dff_drop
# Out:
#                  10874   12499  12593  13039   13424  14281  14331  14426  \
# Geneid
# ENSG00000187634   19.0     1.0   59.0    4.0     5.0   61.0    2.0    1.0
# ENSG00000188976  384.0   649.0  529.0  347.0   440.0  383.0  302.0  324.0
# ENSG00000187961  115.0   158.0  164.0   80.0   171.0  119.0   99.0  133.0
# ENSG00000187583   24.0    21.0   45.0   12.0    16.0   33.0    8.0    5.0
# ENSG00000187642   25.0     5.0   42.0    5.0     3.0   18.0    2.0    2.0
# ...                ...     ...    ...    ...     ...    ...    ...    ...
# ENSG00000212907  385.0   369.0   60.0  138.0   460.0  138.0  173.0  144.0
# ENSG00000198886  976.0  1577.0  379.0  440.0  1508.0  627.0  534.0  406.0
# ENSG00000198786  511.0   763.0  234.0  222.0  1007.0  429.0  203.0  186.0
# ENSG00000198695  346.0   142.0  169.0  158.0   138.0  241.0   65.0   83.0
# ENSG00000198727  766.0  1506.0  405.0  379.0  1316.0  581.0  501.0  328.0
#
#                  15761  16580  ...   4136   41381  4139   60002  60015  \
# Geneid                         ...
# ENSG00000187634   44.0    3.0  ...    43.0    8.0   16.0   29.0    1.0
# ENSG00000188976  336.0  234.0  ...   775.0  369.0  321.0  292.0  344.0
# ENSG00000187961  122.0   44.0  ...   275.0  121.0  101.0  106.0  109.0
# ENSG00000187583   47.0   11.0  ...    71.0   12.0   32.0   27.0   13.0
# ENSG00000187642   26.0    1.0  ...    30.0    2.0   25.0   33.0    1.0
# ...                ...    ...  ...     ...    ...    ...    ...    ...
# ENSG00000212907  151.0   31.0  ...   379.0  257.0  102.0  148.0  176.0
# ENSG00000198886  603.0  168.0  ...  1403.0  652.0  333.0  546.0  669.0
# ENSG00000198786  428.0   83.0  ...   689.0  479.0  230.0  237.0  311.0
# ENSG00000198695  493.0   69.0  ...   236.0  205.0  102.0  136.0   69.0
# ENSG00000198727  517.0  192.0  ...  1026.0  583.0  339.0  461.0  498.0
#
#                   60024   60036  60095  60171   85242
# Geneid
# ENSG00000187634     1.0     3.0    0.0    1.0     1.0
# ENSG00000188976   342.0   858.0  280.0  161.0  1082.0
# ENSG00000187961   105.0   205.0   85.0   71.0   310.0
# ENSG00000187583     7.0    14.0    8.0    6.0    26.0
# ENSG00000187642     3.0     3.0    1.0    1.0     2.0
# ...                 ...     ...    ...    ...     ...
# ENSG00000212907   305.0   507.0  115.0  140.0   881.0
# ENSG00000198886  1231.0  1727.0  480.0  474.0  2173.0
# ENSG00000198786   525.0   848.0  275.0  217.0  1838.0
# ENSG00000198695    86.0   132.0   59.0  142.0    92.0
# ENSG00000198727  1049.0  1260.0  494.0  402.0  2501.0
#
# [16299 rows x 707 columns]

# %%
# to add one so that later when we take log2 we do not end with conflict
dff=dff_drop.add(1)

# %%
#Trimmed Means of M-values (tmm)
dff_tmm = conorm.tmm(dff)
dff_tmm
# Out:
#                       10874        12499       12593       13039        13424  \
# Geneid
# ENSG00000187634   18.663288     1.998614   45.990673    5.709843     5.856627
# ENSG00000188976  359.268287   649.549705  406.250944  397.405093   430.462052
# ENSG00000187961  108.247068   158.889851  126.474351   92.499461   167.889961
# ENSG00000187583   23.329110    21.984759   35.259516   14.845593    16.593775
# ENSG00000187642   24.262274     5.995843   32.959982    6.851812     3.904418
# ...                     ...          ...         ...         ...          ...
# ENSG00000212907  360.201451   369.743678   46.757184  158.733643   449.984141
# ENSG00000198886  911.701601  1576.906823  291.274262  503.608178  1472.941580
# ENSG00000198786  477.780164   763.470731  180.130136  254.659011   983.913262
# ENSG00000198695  323.808040   142.900935  130.306907  181.573017   135.678515
# ENSG00000198727  715.737081  1505.956009  311.203554  433.948090  1285.529530
#
#                       14281       14331       14426       15761       16580  \
# Geneid
# ENSG00000187634   47.672041    3.251635    2.241096   37.632101    4.460318
# ENSG00000188976  295.259090  328.415180  364.178104  281.822625  262.043683
# ENSG00000187961   92.268466  108.387848  150.153434  102.861077   50.178578
# ENSG00000187583   26.142732    9.754906    6.723288   40.140908   13.380954
# ENSG00000187642   14.609174    3.251635    3.361644   22.579261    2.230159
# ...                     ...         ...         ...         ...         ...
# ENSG00000212907  106.877639  188.594856  162.479462  127.112875   35.682544
# ENSG00000198886  482.871637  579.874988  456.063041  505.106426  188.448436
# ENSG00000198786  330.628669  221.111210  209.542478  358.759366   93.666678
# ENSG00000198695  186.074739   71.535980   94.126033  413.116845   78.055565
# ENSG00000198727  447.502059  544.106998  368.660296  433.187299  215.210344
#
#                  ...        4136        41381       4139        60002  \
# Geneid           ...
# ENSG00000187634  ...    34.439895    7.765007   16.323485   27.633633
# ENSG00000188976  ...   607.394515  319.228058  309.186008  269.888484
# ENSG00000187961  ...   216.032070  105.258981   97.940909   98.559958
# ENSG00000187583  ...    56.356192   11.216121   31.686765   25.791391
# ENSG00000187642  ...    24.264472    2.588336   24.965330   31.318118
# ...              ...          ...         ...         ...         ...
# ENSG00000212907  ...   297.435458  222.596862   98.901114  137.247045
# ENSG00000198886  ...  1098.945746  563.394383  320.708468  503.853245
# ENSG00000198786  ...   540.080174  414.133697  221.807354  219.226823
# ENSG00000198695  ...   185.505799  177.732378   98.901114  126.193592
# ENSG00000198727  ...   803.858462  503.862664  326.469698  425.557951
#
#                       60015        60024        60036       60095       60171  \
# Geneid
# ENSG00000187634    2.334217     2.476657     3.936086    1.076306    2.051323
# ENSG00000188976  402.652458   424.746659   845.274409  302.442021  166.157168
# ENSG00000187961  128.381943   131.262816   202.708415   92.562327   73.847630
# ENSG00000187583   16.339520     9.906628    14.760321    9.686755    7.179631
# ENSG00000187642    2.334217     4.953314     3.936086    2.152612    2.051323
# ...                     ...          ...          ...         ...         ...
# ENSG00000212907  206.578218   378.928506   499.882887  124.851510  144.618276
# ENSG00000198886  781.962745  1525.620653  1700.389033  517.703246  487.189227
# ENSG00000198786  364.137875   651.360766   835.434195  297.060490  223.594214
# ENSG00000198695   81.697600   107.734575   130.874850   64.578367  146.669599
# ENSG00000198727  582.387179  1300.244875  1240.851024  532.771532  413.341597
#
#                        85242
# Geneid
# ENSG00000187634     2.197449
# ENSG00000188976  1189.918846
# ENSG00000187961   341.703381
# ENSG00000187583    29.665567
# ENSG00000187642     3.296174
# ...                      ...
# ENSG00000212907   969.075182
# ENSG00000198886  2388.627490
# ENSG00000198786  2020.554717
# ENSG00000198695   102.181397
# ENSG00000198727  2749.009191
#
# [16299 rows x 707 columns]

# %%
#log2 normalisation
log_tmm=np.log2(dff_tmm)
data_log_tmm=pd.DataFrame(log_tmm)
data_log_tmm
# Out:
#                     10874      12499     12593     13039      13424     14281  \
# Geneid
# ENSG00000187634  4.222131   0.999000  5.523269  2.513451   2.550070  5.575071
# ENSG00000188976  8.488918   9.343296  8.666227  8.634467   8.749742  8.205838
# ENSG00000187961  6.758184   7.311883  6.982701  6.531373   7.391372  6.527766
# ENSG00000187583  4.544059   4.458432  5.139941  3.891963   4.052570  4.708338
# ENSG00000187642  4.600643   2.583963  5.042644  2.776486   1.965107  3.868803
# ...                   ...        ...       ...       ...        ...       ...
# ENSG00000212907  8.492660   8.530382  5.547116  7.310464   8.813730  6.739816
# ENSG00000198886  9.832418  10.622882  8.186234  8.976158  10.524484  8.915496
# ENSG00000198786  8.900203   9.576429  7.492896  7.992423   9.942387  8.369068
# ENSG00000198695  8.338995   7.158872  7.025770  7.504406   7.084048  7.539738
# ENSG00000198727  9.483286  10.556464  8.281715  8.761379  10.328147  8.805751
#
#                     14331     14426     15761     16580  ...      4136   \
# Geneid                                                   ...
# ENSG00000187634  1.701166  1.164204  5.233892  2.157147  ...   5.106009
# ENSG00000188976  8.359377  8.508500  8.138644  8.033664  ...   9.246490
# ENSG00000187961  6.760059  7.230294  6.684553  5.649000  ...   7.755102
# ENSG00000187583  3.286128  2.749167  5.327001  3.742109  ...   5.816502
# ENSG00000187642  1.701166  1.749167  4.496926  1.157147  ...   4.600774
# ...                   ...       ...       ...       ...  ...        ...
# ENSG00000212907  7.559147  7.344114  6.989966  5.157147  ...   8.216433
# ENSG00000198886  9.179598  8.833089  8.980444  7.558026  ...  10.101904
# ENSG00000198786  7.788628  7.711099  8.486873  6.549464  ...   9.077030
# ENSG00000198695  6.160597  6.556522  8.690406  6.286430  ...   7.535320
# ENSG00000198727  9.087747  8.526148  8.758847  7.749604  ...   9.650798
#
#                     41381     4139      60002     60015      60024      60036  \
# Geneid
# ENSG00000187634  2.956987  4.028877  4.788353  1.222939   1.308394   1.976762
# ENSG00000188976  8.318444  8.272331  8.076220  8.653391   8.730459   9.723276
# ENSG00000187961  6.717800  6.613840  6.622930  7.004298   7.036314   7.663262
# ENSG00000187583  3.487502  4.985808  4.688818  4.030294   3.308394   3.883652
# ENSG00000187642  1.372025  4.641854  4.968926  1.222939   2.308394   1.976762
# ...                   ...       ...       ...       ...        ...        ...
# ENSG00000212907  7.798289  6.627915  7.100631  7.690544   8.565782   8.965446
# ENSG00000198886  9.138001  8.325119  8.976860  9.610956  10.575181  10.731649
# ENSG00000198786  8.693953  7.793163  7.776281  8.508341   9.347313   9.706382
# ENSG00000198695  7.473563  6.627915  6.979495  6.352222   6.751338   7.032044
# ENSG00000198727  8.976887  8.350805  8.733212  9.185835  10.344568  10.277114
#
#                     60095     60171      85242
# Geneid
# ENSG00000187634  0.106088  1.036555   1.135830
# ENSG00000188976  8.240515  7.376405  10.216647
# ENSG00000187961  6.532353  6.206480   8.416601
# ENSG00000187583  3.276013  2.843910   4.890717
# ENSG00000187642  1.106088  1.036555   1.720792
# ...                   ...       ...        ...
# ENSG00000212907  6.964069  7.176106   9.920465
# ENSG00000198886  9.015982  8.928338  11.221966
# ENSG00000198786  8.214613  7.804739  10.980536
# ENSG00000198695  6.012979  7.196426   6.674989
# ENSG00000198727  9.057373  8.691191  11.424696
#
# [16299 rows x 707 columns]

# %%
#the first step to get the cpm norm is these two lines
#nm = norm()
#nm.cpm(df=dff)
#here is the cpm norm taking step 
#cpm_df = nm.cpm_norm
#cpm_df.head(5)

# %%
#loading the quant diagnosis: prediction

quant_predict1=pd.read_csv(path1/"the_diagnosis_count_ir2.txt", header=None ,index_col=[0])
quant_predict=quant_predict1.rename(columns=quant_predict1.iloc[0]).drop(quant_predict1.index[0]).reset_index(drop=True)

# %%
#transposed matrix
t_quant=data_log_tmm.T
t_quant
# Out:
# Geneid  ENSG00000187634  ENSG00000188976  ENSG00000187961  ENSG00000187583  \
# 10874          4.222131         8.488918         6.758184         4.544059
# 12499          0.999000         9.343296         7.311883         4.458432
# 12593          5.523269         8.666227         6.982701         5.139941
# 13039          2.513451         8.634467         6.531373         3.891963
# 13424          2.550070         8.749742         7.391372         4.052570
# ...                 ...              ...              ...              ...
# 60024          1.308394         8.730459         7.036314         3.308394
# 60036          1.976762         9.723276         7.663262         3.883652
# 60095          0.106088         8.240515         6.532353         3.276013
# 60171          1.036555         7.376405         6.206480         2.843910
# 85242          1.135830        10.216647         8.416601         4.890717
#
# Geneid  ENSG00000187642  ENSG00000188290  ENSG00000187608  ENSG00000188157  \
# 10874          4.600643         6.987666        11.408988         6.807094
# 12499          2.583963         6.856981        10.004625         6.917863
# 12593          5.042644         7.461869         9.894828         7.155538
# 13039          2.776486         9.249515        13.999180         8.030727
# 13424          1.965107         7.791656        10.439827         6.357425
# ...                 ...              ...              ...              ...
# 60024          2.308394         6.395857        10.465741         6.191037
# 60036          1.976762         7.576674        11.052909         7.508143
# 60095          1.106088         6.964069         9.391491         5.276013
# 60171          1.036555         6.186302         9.600704         3.943445
# 85242          1.720792         7.201919         9.926993         7.651530
#
# Geneid  ENSG00000131591  ENSG00000162571  ...  ENSG00000198712  \
# 10874          7.301083         3.707558  ...        10.992960
# 12499          8.242174         1.999000  ...        11.493856
# 12593          7.703842         4.825832  ...         9.102208
# 13039          7.011702         2.513451  ...         9.626151
# 13424          7.778889         1.965107  ...        10.928726
# ...                 ...              ...  ...              ...
# 60024          7.498219         2.630322  ...        10.827047
# 60036          8.666760         3.146687  ...        11.401978
# 60095          7.139511         1.106088  ...         9.573694
# 60171          6.445946         1.036555  ...         9.579587
# 85242          8.739456         1.135830  ...        11.622665
#
# Geneid  ENSG00000228253  ENSG00000198899  ENSG00000198938  ENSG00000198840  \
# 10874          5.600643         8.439362        12.715787        10.115736
# 12499          5.246928         9.316413        13.155873        10.055638
# 12593          4.423734         6.786304        11.201811         7.801254
# 13039          4.946411         7.410692        11.572525         8.992423
# 13424          5.519696         9.028502        12.372375         9.252820
# ...                 ...              ...              ...              ...
# 60024          5.665946         9.153884        13.097520        10.224273
# 60036          5.784117         9.186215        13.050568         9.943988
# 60095          4.691051         7.660677        11.577256         8.799575
# 60171          4.284482         6.882045        11.642960         8.891423
# 85242          5.345283         9.559996        11.484558         8.259951
#
# Geneid  ENSG00000212907  ENSG00000198886  ENSG00000198786  ENSG00000198695  \
# 10874          8.492660         9.832418         8.900203         8.338995
# 12499          8.530382        10.622882         9.576429         7.158872
# 12593          5.547116         8.186234         7.492896         7.025770
# 13039          7.310464         8.976158         7.992423         7.504406
# 13424          8.813730        10.524484         9.942387         7.084048
# ...                 ...              ...              ...              ...
# 60024          8.565782        10.575181         9.347313         6.751338
# 60036          8.965446        10.731649         9.706382         7.032044
# 60095          6.964069         9.015982         8.214613         6.012979
# 60171          7.176106         8.928338         7.804739         7.196426
# 85242          9.920465        11.221966        10.980536         6.674989
#
# Geneid  ENSG00000198727
# 10874          9.483286
# 12499         10.556464
# 12593          8.281715
# 13039          8.761379
# 13424         10.328147
# ...                 ...
# 60024         10.344568
# 60036         10.277114
# 60095          9.057373
# 60171          8.691191
# 85242         11.424696
#
# [707 rows x 16299 columns]

# %%
searchfor = ['Healthy Control', "Parkinson's Disease"]

# %%
#we just pick those that are either health control or parkinson diseases
quant_p=quant_predict[quant_predict['COHORT_DEFINITION'].astype(str).str.contains('|'.join(searchfor))]

# %%
quant_new_predict=quant_p['BL_PATNO']

# %%
r_quant_patients=[int(x) for x in quant_new_predict]

# %%
#here we select those rna-seq data that includes both health control and parkinson 
selected_quant_rna=data_log_tmm[r_quant_patients]

# %%
select_quant_rna=selected_quant_rna.T

# %%
quant_p['COHORT_DEFINITION'].replace(['Healthy Control', "Parkinson's Disease"],
                        [0, 1], inplace=True)
# Out:
# /tmp/ipykernel_6388/93247712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   quant_p['COHORT_DEFINITION'].replace(['Healthy Control', "Parkinson's Disease"],

# %%
#here we make the model
bst_q = XGBClassifier(n_estimators=100, max_depth=30, learning_rate=0.2, objective='reg:logistic')

# %%
# %%time
#here we repeat the machine learning procedure for k times XGboost, logistic regression!

k=5
g0=[]
p0=[]
for i in range(k):
    X_trainq, X_testq, y_trainq, y_testq = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
    logr=bst_q.fit(X_trainq, y_trainq)
    accuracy = accuracy_score(y_testq, logr.predict(X_testq))
    roc_score = roc_auc_score(y_testq,logr.predict(X_testq))
    g= (accuracy * 100.0)
    p= (roc_score*100.0)
    g0+=[g]
    p0+=[p]
aa1=round(sum(g0)/k)
aa2=round(sum(p0)/k)
aa3=round(np.std(g0))
aa4=round(np.std(p0))
print("average accuracy:",aa1)
print("average roc_auc score:",aa2)
print("accuracy std:",aa3)
print("auc_roc score std:",aa4)
# Out:
# average accuracy: 64
# average roc_auc score: 52
# accuracy std: 3
# auc_roc score std: 1
# CPU times: user 15min 2s, sys: 11 s, total: 15min 13s
# Wall time: 7min 47s

# %% [raw]
# %%time
# #here we repeat the machine learning procedure for k times
# model_gb = GradientBoostingClassifier()
#
# k_gb=5
# g0_gb=[]
# p0_gb=[]
# for i in range(k_gb):
#     X_train_gb, X_test_gb, y_train_gb, y_test_gb = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
#     m_gb=model_gb.fit(X_train_gb, y_train_gb)
#     accuracy_gb = accuracy_score(y_test_gb, m_gb.predict(X_test_gb))
#     roc_score_gb = roc_auc_score(y_test_gb,m_gb.predict(X_test_gb))
#     g_gb= (accuracy_gb * 100.0)
#     p_gb= (roc_score_gb*100.0)
#     g0_gb+=[g_gb]
#     p0_gb+=[p_gb]
# gb1=round(sum(g0_gb)/k_gb)
# gb2=round(sum(p0_gb)/k_gb)
# gb3=round(np.std(g0_gb))
# gb4=round(np.std(p0_gb))
# print("average accuracy:",gb1)
# print("average roc_auc score:",gb2)
# print("accuracy std:",gb3)
# print("auc_roc score std:",gb4)

# %%
fl=[]
for i in range(5):
    fl+=[i]
print("ki:",fl)
# Out:
# ki: [0, 1, 2, 3, 4]

# %%
# %%time
model_RF = RandomForestClassifier(n_estimators=150)

# here we also make the code balanced with the provided data.

k=2
g0=[]
m0=[]

for i in range(k):
    X_trainq, X_testq, y_trainq, y_testq = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
    classes_weights = class_weight.compute_sample_weight(class_weight='balanced',y=y_trainq)
    model_RF.fit(X_trainq, y_trainq,sample_weight=classes_weights )
    preds_q = model_RF.predict(X_testq)
    accuracy = accuracy_score(y_testq, preds_q)
    roc_score=roc_auc_score(y_testq,preds_q)
    g= (accuracy * 100.0)
    m= (roc_score * 100.0)
    g0+=[g]
    m0+=[m]
cc1=round(sum(g0)/k,2)
cc2=round(sum(m0)/k,2)
print("average accuracy:",cc1)
print("average roc_auc score:",cc2)
# Out:
# average accuracy: 63.84
# average roc_auc score: 49.73
# CPU times: user 8.51 s, sys: 257 ms, total: 8.77 s
# Wall time: 8.93 s

# %% [markdown]
# # Selecting Features

# %%
sel = SelectFromModel(model_RF)
sel.fit(X_trainq, y_trainq)
selected_feat= X_trainq.columns[(sel.get_support())]
selected_feat
# Out:
# Index(['ENSG00000188976', 'ENSG00000187961', 'ENSG00000187583',
#        'ENSG00000188290', 'ENSG00000188157', 'ENSG00000162571',
#        'ENSG00000184163', 'ENSG00000169962', 'ENSG00000160072',
#        'ENSG00000205090',
#        ...
#        'ENSG00000154620', 'ENSG00000165246', 'ENSG00000012817',
#        'ENSG00000198888', 'ENSG00000198763', 'ENSG00000198712',
#        'ENSG00000198938', 'ENSG00000212907', 'ENSG00000198695',
#        'ENSG00000198727'],
#       dtype='object', name='Geneid', length=4124)

# %%
coeff = {}
for idx, item in enumerate(model_RF.best_estimator_.named_steps["classifier"].feature_importances_):
    coeff[new_cols[idx]] = item
for key in sorted(coeff,key=lambda x: abs(coeff[x]),reverse=True):
    print("{0:40}:{1}".format(key,coeff[key]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6388/2777839466.py in <module>
#       1 coeff = {}
# ----> 2 for idx, item in enumerate(model_RF.best_estimator_.named_steps["classifier"].feature_importances_):
#       3     coeff[new_cols[idx]] = item
#       4 for key in sorted(coeff,key=lambda x: abs(coeff[x]),reverse=True):
#       5     print("{0:40}:{1}".format(key,coeff[key]))
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'best_estimator_'

# %% [markdown]
# # Hyperparameter tuning for Random forest

# %%
n_estimators=[int(x) for x in np.linspace(start=5, stop=70, num=10)]
max_depth=[2, 4, 6, 10, 12, 18, 20]
min_samples_split=[2,5]
max_features=['sqrt']
min_samples_leaf=[1,2]
bootstrap=[False]

# %%
#creating the param grid
param_grid={'n_estimators':n_estimators,
           'max_depth':max_depth,
           'min_samples_split':min_samples_split,
           'max_features':max_features,
           'min_samples_leaf':min_samples_leaf,
           'bootstrap':bootstrap}
print(param_grid)

# %%
from sklearn.model_selection import GridSearchCV

# %%
mdl_RF = RandomForestClassifier()

# %%
rf_Grid = GridSearchCV(estimator = mdl_RF, param_grid = param_grid,
                      cv = 3, verbose = 2, n_jobs = 4)

# %%
# %%time
rf_Grid.fit(X_trainq, y_trainq)

# %%
X_trainq.isna()

# %%
rf_Grid.best_params_

# %%
hp_RF = RandomForestClassifier(bootstrap=False, max_depth=10, n_estimators=42, max_features='sqrt', min_samples_leaf=1, min_samples_split=2)

# %% [raw]
# %%time
#
# # here we also make the code balanced with the provided data.
#
# k=5
# g0=[]
# m0=[]
#
# for i in range(k):
#     X_trainq, X_testq, y_trainq, y_testq = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
#     classes_weights = class_weight.compute_sample_weight(class_weight='balanced',y=y_trainq)
#     hp_RF.fit(X_trainq, y_trainq,sample_weight=classes_weights )
#     preds_q = hp_RF.predict(X_testq)
#     accuracy = accuracy_score(y_testq, preds_q)
#     roc_score=roc_auc_score(y_testq,preds_q)
#     g= (accuracy * 100.0)
#     m= (roc_score * 100.0)
#     g0+=[g]
#     m0+=[m]
# cc1=round(sum(g0)/k,2)
# cc2=round(sum(m0)/k,2)
# print("average accuracy:",cc1)
# print("average roc_auc score:",cc2)

# %% [raw]
# hp2_RF = RandomForestClassifier(bootstrap=False, max_depth=2, n_estimators=12, max_features='sqrt', min_samples_leaf=1, min_samples_split=2)

# %% [raw]
# %%time
#
# # here we also make the code balanced with the provided data.
#
# k=5
# g0=[]
# m0=[]
#
# for i in range(k):
#     X_trainq, X_testq, y_trainq, y_testq = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.3)
#     classes_weights = class_weight.compute_sample_weight(class_weight='balanced',y=y_trainq)
#     hp2_RF.fit(X_trainq, y_trainq,sample_weight=classes_weights )
#     preds_q = hp2_RF.predict(X_testq)
#     accuracy = accuracy_score(y_testq, preds_q)
#     roc_score=roc_auc_score(y_testq,preds_q)
#     g= (accuracy * 100.0)
#     m= (roc_score * 100.0)
#     g0+=[g]
#     m0+=[m]
# cc1=round(sum(g0)/k,2)
# cc2=round(sum(m0)/k,2)
# print("average accuracy:",cc1)
# print("average roc_auc score:",cc2)

# %% [markdown]
# # check the data spiliting correctness

# %% [raw]
# %%time
#
# # here we also make the code balanced with the provided data.
#
# k=3
# g0=[]
# m0=[]
# g0_tr_tr=[]
# m0_tr_tr=[]
#
# g0_te=[]
# m0_te=[]
# g0_te_te=[]
# m0_te_te=[]
#
# for i in range(k):
#     X_trainq, X_testq, y_trainq, y_testq = train_test_split(select_quant_rna,quant_p['COHORT_DEFINITION'], test_size=.5)
#     classes_weights = class_weight.compute_sample_weight(class_weight='balanced',y=y_trainq)
#
#     trh_RF=hp2_RF.fit(X_trainq, y_trainq,sample_weight=classes_weights )
#     teh_RF=hp2_RF.fit(X_testq, y_testq )
#
#     preds_q = trh_RF.predict(X_testq)
#     preds_tr_tr = trh_RF.predict(X_trainq)
#
#     preds_q_te = teh_RF.predict(X_trainq)
#     preds_te_te = teh_RF.predict(X_testq)
#
#
#     accuracy = accuracy_score(y_testq, preds_q)
#     roc_score=roc_auc_score(y_testq,preds_q)
#
#     accuracy_te = accuracy_score(y_trainq, preds_q_te)
#     roc_score_te=roc_auc_score(y_trainq,preds_q_te)
#
#     accuracy_tr_tr = accuracy_score(y_trainq, preds_tr_tr)
#     roc_score_tr_tr=roc_auc_score(y_trainq,preds_tr_tr)
#     g= (accuracy * 100.0)
#     m= (roc_score * 100.0)
#
#     g_te= (accuracy_te * 100.0)
#     m_te= (roc_score_te* 100.0)
#
#     g_tr_tr= (accuracy_tr_tr * 100.0)
#     m_tr_tr= (roc_score_tr_tr* 100.0)
#     g0+=[g]
#     m0+=[m]
#
#     g0_te+=[g_te]
#     m0_te+=[m_te]
#
#     g0_tr_tr+=[g_tr_tr]
#     m0_tr_tr+=[m_tr_tr]
#
# cc1=round(sum(g0)/k,2)
# cc2=round(sum(m0)/k,2)
#
# cc1_te=round(sum(g0_te)/k,2)
# cc2_te=round(sum(m0_te)/k,2)
#
# cc1_tr_tr=round(sum(g0_tr_tr)/k,2)
# cc2_tr_tr=round(sum(m0_tr_tr)/k,2)
#
# print("average accuracy-fit:training, predict:test:",cc1)
# print("average roc_auc score-fit:training, predict:test:",cc2)
# print('------------------------------')
# print("average accuracy-fit:training, predict:training:",cc1_tr_tr)
# print("average roc_auc score-fit:training, predict:training:",cc2_tr_tr)
# print('------------------------------')
# print("average accuracy-fit:test, predict:train:",cc1_te)
# print("average roc_auc score-fit:test, predict:train:",cc2_te)
# print('------------------------------')
# #print("average accuracy-fit:test predict:training:",cc1)
# #print("average roc_auc score-fit:test, predict:training:",cc2)

# %%
print('Accuracy:  ', accuracy_score(y_testq,bst_q.predict(X_testq)))
print('Precision: ', precision_score(y_testq,bst_q.predict(X_testq)))
print('Recall:    ', recall_score(y_testq,bst_q.predict(X_testq)))
print('F1:        ', f1_score(y_testq,bst_q.predict(X_testq)))
print('ROC-AUC:   ', roc_auc_score(y_testq,bst_q.predict(X_testq)))
print('\nConfusion Matrix\n{0}'.format(confusion_matrix(y_testq,bst_q.predict(X_testq))))

# %%
print('Accuracy:  ', accuracy_score(y_trainq,bst_q.predict(X_trainq)))
print('Precision: ', precision_score(y_trainq,bst_q.predict(X_trainq)))
print('Recall:    ', recall_score(y_trainq,bst_q.predict(X_trainq)))
print('F1:        ', f1_score(y_trainq,bst_q.predict(X_trainq)))
print('ROC-AUC:   ', roc_auc_score(y_trainq,bst_q.predict(X_trainq)))
print('\nConfusion Matrix\n{0}'.format(confusion_matrix(y_trainq,bst_q.predict(X_trainq))))

# %% [markdown]
# *confusion matrix* TN, FP; FN, TP

# %%
roc = roc_curve(y_testq,bst_q.predict_proba(X_testq)[:,1])
pr  = precision_recall_curve(y_testq,bst_q.predict_proba(X_testq)[:,1])

f = plt.figure(figsize=(20,7))
ax = f.add_subplot(121)
ax.plot(roc[0],roc[1])
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('False Positive Rate')
ax.set_title('ROC Curve')
ax.grid(which='both')
ax = f.add_subplot(122)
ax.plot(pr[1],pr[0])
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
ax.set_title('PR-curve')
ax.grid(which='both')
plt.show()

# %%
roc = roc_curve(y_trainq,bst_q.predict_proba(X_trainq)[:,1])
pr  = precision_recall_curve(y_trainq,bst_q.predict_proba(X_trainq)[:,1])

f = plt.figure(figsize=(20,7))
ax = f.add_subplot(121)
ax.plot(roc[0],roc[1])
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('False Positive Rate')
ax.set_title('ROC Curve')
ax.grid(which='both')
ax = f.add_subplot(122)
ax.plot(pr[1],pr[0])
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
ax.set_title('PR-curve')
ax.grid(which='both')
plt.show()

# %%
roc = roc_curve(y_train_gb,m_gb.predict_proba(X_train_gb)[:,1])
pr  = precision_recall_curve(y_train_gb,m_gb.predict_proba(X_train_gb)[:,1])

f = plt.figure(figsize=(20,7))
ax = f.add_subplot(121)
ax.plot(roc[0],roc[1])
ax.set_ylabel('True Positive Rate')
ax.set_xlabel('False Positive Rate')
ax.set_title('ROC Curve')
ax.grid(which='both')
ax = f.add_subplot(122)
ax.plot(pr[1],pr[0])
ax.set_ylabel('Precision')
ax.set_xlabel('Recall')
ax.set_title('PR-curve')
ax.grid(which='both')
plt.show()
