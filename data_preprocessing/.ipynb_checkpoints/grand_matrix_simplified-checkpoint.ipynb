# %% [markdown]
# # This code is written for the extraction of last column of
# # the each patients for the base visit.
# # Written by Zainab Nazari, last modify: 18.05.2023 15:46

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import functools

# %%
#!pip install dask[complete]

# %%
import dask.dataframe as dd

# %% [markdown]
#  We put the main path to the folder where 'counts' files are there.

# %%
path1=Path("/scratch/znazari/PPMI_ver_sep2022/RNA_Seq_data/star_ir2/counts/")

# %% [markdown]
#  We read the file: in the bl.txt is written the name of all files.

# %%
bl_files=pd.read_csv(path1/"bl.txt", header=None )

# %%
bl_files

# %%
len(bl_files)
# Out:
# 1537

# %% [markdown]
#  We define a function where we can take the second phrase seperated by dot. The second phrase
# is the patient ID. So with this functin we want to get the patient IDs from their file's name

# %%
def function_names(fname):
    tokens=fname.split('.')
    return tokens[1]

# %%
def merge(a,b):
    a.iloc[:,-1:].reset_index(drop=False).merge(b.iloc[:,-1:].reset_index(drop=True), left_index=True, right_index=True)
    return a

# %%
def merge_df(a,b):
    return a.reset_index(drop=True).merge(b.iloc[:,-1:].reset_index(drop=True),left_index=True, right_index=True)

# %% [markdown]
#  here we go through all file names and extract their patient IDs and put into a list
#  So here we have the list of patient IDs for those whom they have put the data for their base visit

# %%
bl_list=[]
for i in range(len(bl_files)):
    bl_list=bl_list+[function_names(bl_files.iloc[i][0])]

# %%
type(bl_list)
# Out:
# list

# %% [markdown]
#  here we read all the files with with base visit from the count folder where we have all the files
#  for all the patients and all the visit.
#  here we have a list of all files with base visit.

# %%
# %%time
list_bl_files=[]
for i in range(len(bl_files)):
    list_bl_files=list_bl_files+[dd.read_csv(path1/bl_files.iloc[i][0],skiprows=1,delimiter='\t')]
# Out:
# CPU times: user 7.47 s, sys: 2.28 s, total: 9.74 s
# Wall time: 12.5 s

# %%
list_bl_files[0]
# Out:
# Dask DataFrame Structure:
#                Geneid     Chr   Start     End  Strand Length bams/inQueue_PPMI-Phase1-IR1.10874.BL.PP0047-6931.5104-SL-0659.longRNA-NEBKAP.star.bam
# npartitions=1
#                object  object  object  object  object  int64                                                                                  int64
#                   ...     ...     ...     ...     ...    ...                                                                                    ...
# Dask Name: read-csv, 1 tasks

# %%
# here  we take the last column of each file? 
for i in range(len(bl_list)):
    list_bl_files[i].columns = list(list_bl_files[i].columns[:-1])+[bl_list[i]]

# %%
list_bl_files[1]
# Out:
# Dask DataFrame Structure:
#                Geneid     Chr   Start     End  Strand Length  12499
# npartitions=1
#                object  object  object  object  object  int64  int64
#                   ...     ...     ...     ...     ...    ...    ...
# Dask Name: rename, 2 tasks

# %%
# first two columns we merege 

first_two_elements_merge_bl=list_bl_files[0].compute().iloc[:,-1:].reset_index(drop=False).merge(list_bl_files[1].compute().iloc[:,-1:].reset_index(drop=True), left_index=True, right_index=True)

# %%
dd_first_two_elements_merge_bl = dd.from_pandas(first_two_elements_merge_bl, npartitions=3)

# %%
list_bl_files_conv=[dd_first_two_elements_merge_bl]+list_bl_files[2:]

del list_bl_files

# %%
list_bl_files_conv
# Out:
# [Dask DataFrame Structure:
#                 index  10874  12499
#  npartitions=3
#  0              int64  int64  int64
#  19274            ...    ...    ...
#  38548            ...    ...    ...
#  57819            ...    ...    ...
#  Dask Name: from_pandas, 3 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  12593
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  13039
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  13424
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  14281
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  14331
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  14426
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  15761
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  16580
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  16785
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  17608
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  18567
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3000
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3001
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3002
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3003
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3004
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3008
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3010
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3011
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3012
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3013
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3014
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3016
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3020
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3023
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3024
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3026
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3027
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3029
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3050
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3052
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3053
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3055
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3057
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3058
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3059
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3060
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3062
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3064
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3068
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3069
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3072
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3073
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3074
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3075
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3076
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3078
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3079
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3081
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3082
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3083
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3087
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3089
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3100
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3104
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3105
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3106
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3107
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3108
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3110
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3118
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3119
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3120
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3123
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3124
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3125
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3128
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3130
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3131
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3132
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3134
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3150
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3151
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3156
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3161
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3162
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3166
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3168
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3169
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3170
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3173
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3174
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3176
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3179
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3180
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3181
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3182
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3183
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3184
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3185
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3186
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3188
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3189
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3190
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3191
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3200
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3201
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3203
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3206
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3207
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3211
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3214
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3216
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3217
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3218
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3221
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3225
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3226
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3227
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3229
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3230
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3232
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3233
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3234
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3237
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3251
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3252
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3256
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3257
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3262
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3264
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3268
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3269
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3272
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3274
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3276
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3277
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3279
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3280
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3281
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3282
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3284
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3285
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3288
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3300
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3301
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3304
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3305
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3307
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3308
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3309
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3310
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3312
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   3314
#  npartitions=1
#                 object  object  object  object  object  int64  int64
# ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40777
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40778
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40779
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40780
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40781
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40782
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40783
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40784
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40789
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4079
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length 40803R
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40806
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40811
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length 40816R
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40819
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4081
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40830
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4084
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40866
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40898
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4091
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length 40922R
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40938
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40977
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  40989
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4102
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41037
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41044
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41052
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41055
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41065
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41069
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4108
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41113
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41141
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41154
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4115
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41165
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41170
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41172
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41181
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4123
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41246
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4125
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41279
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length   4127
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41284
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  Dask DataFrame Structure:
#                 Geneid     Chr   Start     End  Strand Length  41297
#  npartitions=1
#                 object  object  object  object  object  int64  int64
#                    ...     ...     ...     ...     ...    ...    ...
#  Dask Name: rename, 2 tasks,
#  ...]

# %%
merged_bl=functools.reduce(merge_df,list_bl_files_conv)
del list_bl_files_conv
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_27787/3053894131.py in <module>
# ----> 1 merged_bl=functools.reduce(merge_df,list_bl_files_conv)
#       2 del list_bl_files_conv
#
# /tmp/ipykernel_27787/182380995.py in merge_df(a, b)
#       1 def merge_df(a,b):
# ----> 2     return a.reset_index(drop=True).merge(b.iloc[:,-1:].reset_index(drop=True),left_index=True, right_index=True)
#
# ~/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py in reset_index(self, drop)
#     593             Do not try to insert index into dataframe columns.
#     594         """
# --> 595         return self.map_partitions(
#     596             M.reset_index, drop=drop, enforce_metadata=False
#     597         ).clear_divisions()
#
# ~/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py in map_partitions(self, func, *args, **kwargs)
#     864         None as the division.
#     865         """
# --> 866         return map_partitions(func, self, *args, **kwargs)
#     867
#     868     @insert_meta_param_description(pad=12)
#
# ~/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py in map_partitions(func, meta, enforce_metadata, transform_divisions, align_dataframes, *args, **kwargs)
#    6545
#    6546     graph = HighLevelGraph.from_collections(name, dsk, dependencies=dependencies)
# -> 6547     return new_dd_object(graph, name, meta, divisions)
#    6548
#    6549
#
# ~/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py in new_dd_object(dsk, name, meta, divisions, parent_meta)
#    7655     """
#    7656     if has_parallel_type(meta):
# -> 7657         return get_parallel_type(meta)(dsk, name, meta, divisions)
#    7658     elif is_arraylike(meta) and meta.shape:
#    7659         import dask.array as da
#
# ~/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py in __init__(self, dsk, name, meta, divisions)
#    4325                 "type": typename(type(self)),
#    4326                 "dataframe_type": typename(type(self._meta)),
# -> 4327                 "series_dtypes": {
#    4328                     col: self._meta[col].dtype
#    4329                     if hasattr(self._meta[col], "dtype")
#
# ~/anaconda3/lib/python3.9/site-packages/dask/dataframe/core.py in <dictcomp>(.0)
#    4327                 "series_dtypes": {
#    4328                     col: self._meta[col].dtype
# -> 4329                     if hasattr(self._meta[col], "dtype")
#    4330                     else None
#    4331                     for col in self._meta.columns
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3472                 if isinstance(self.columns, MultiIndex):
#    3473                     return self._getitem_multilevel(key)
# -> 3474                 return self._get_item_cache(key)
#    3475
#    3476         # Do we have a slicer (on rows)?
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _get_item_cache(self, item)
#    3930
#    3931             loc = self.columns.get_loc(item)
# -> 3932             res = self._ixs(loc, axis=1)
#    3933
#    3934             cache[item] = res
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    3443
#    3444             # this is a cached value, mark it so
# -> 3445             result._set_as_cached(label, self)
#    3446             return result
#    3447
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _set_as_cached(self, item, cacher)
#    1236             del self._cacher
#    1237
# -> 1238     def _set_as_cached(self, item, cacher) -> None:
#    1239         """
#    1240         Set the _cacher attribute on the calling object with a weakref to
#
# KeyboardInterrupt:

# %%
merged_bl

# %%
merged_bl.to_csv("random_test_bl_matrix_counts_ir2.txt",  index=False)
