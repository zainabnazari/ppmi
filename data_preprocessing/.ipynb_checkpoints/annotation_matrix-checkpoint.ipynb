# %%
import pandas as pd
import numpy as np
from pathlib import Path
import functools

# %%
path1=Path("/home/znazari/")

# %%
path2=Path("/scratch/znazari/PPMI_ver_sep2022/RNA_Seq_data/star_ir2/quant/")

# %%
file_rand=pd.read_csv(path2/"PPMI-Phase2-IR2.92834.V04.0002325630.5104-SL-4052.longRNA-NEBKAP.salmon-gtf.genes.sf",delimiter='\t', header=None )

# %%
file_rand2=file_rand.rename(columns=file_rand.iloc[0]).drop(file_rand.index[0]).reset_index(drop=True)

# %%
file_rand2
# Out:
#                     Name   Length EffectiveLength        TPM  NumReads
# 0      ENSG00000198900.5      297              94    141.961       215
# 1      ENSG00000215515.2     3390         1953.77          0         0
# 2      ENSG00000215399.2     1273         792.992          0         0
# 3      ENSG00000196331.5     1238         1015.25  0.0266166  0.435378
# 4      ENSG00000206044.3     1769             351          0         0
# ...                  ...      ...             ...        ...       ...
# 34564  ENSG00000187210.8  894.435          911.71    30.6954    903.65
# 34565  ENSG00000263426.1     1600             351          0         0
# 34566  ENSG00000264729.1      611             303          0         0
# 34567  ENSG00000263919.1      260              75          0         0
# 34568  ENSG00000173894.6     2664         3413.86    6.79566   373.782
#
# [34569 rows x 5 columns]

# %%
single_df=file_rand2[['Name']]

# %%
single_df
# Out:
#                     Name
# 0      ENSG00000198900.5
# 1      ENSG00000215515.2
# 2      ENSG00000215399.2
# 3      ENSG00000196331.5
# 4      ENSG00000206044.3
# ...                  ...
# 34564  ENSG00000187210.8
# 34565  ENSG00000263426.1
# 34566  ENSG00000264729.1
# 34567  ENSG00000263919.1
# 34568  ENSG00000173894.6
#
# [34569 rows x 1 columns]

# %%
single_df.iloc[0][0]
# Out:
# 'ENSG00000198900.5'

# %%
def function_names(fname):
    tokens=fname.split('.')
    return tokens[0]

# %%
all_rows=len(file_rand2.index)
for i in range(all_rows):
    single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# Out:
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# ...
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# /tmp/ipykernel_28815/1350503334.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   single_df.loc[i,['Name']]=function_names(single_df.loc[i][0])
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
single_dff=single_df

# %%
single_dff
# Out:
#                   Name
# 0      ENSG00000198900
# 1      ENSG00000215515
# 2      ENSG00000215399
# 3      ENSG00000196331
# 4      ENSG00000206044
# ...                ...
# 34564  ENSG00000187210
# 34565  ENSG00000263426
# 34566  ENSG00000264729
# 34567  ENSG00000263919
# 34568  ENSG00000173894
#
# [34569 rows x 1 columns]

# %%
df_mine = single_dff.rename(columns={'Name': 'Ensembl gene ID'})

# %%
df_mine
# Out:
#        Ensembl gene ID
# 0      ENSG00000198900
# 1      ENSG00000215515
# 2      ENSG00000215399
# 3      ENSG00000196331
# 4      ENSG00000206044
# ...                ...
# 34564  ENSG00000187210
# 34565  ENSG00000263426
# 34566  ENSG00000264729
# 34567  ENSG00000263919
# 34568  ENSG00000173894
#
# [34569 rows x 1 columns]

# %%
function_names(file_rand2.loc[0][0])
# Out:
# 'ENSG00000198900'

# %%
result_=pd.read_csv('results.txt', on_bad_lines='skip',delimiter='\t', header=None )

# %%
result_3=result_.rename(columns=result_.iloc[0]).drop(result_.index[0]).reset_index(drop=True)

# %%
result_3
# Out:
#           HGNC ID    Status Approved symbol  \
# 0          HGNC:5  Approved            A1BG
# 1      HGNC:37133  Approved        A1BG-AS1
# 2      HGNC:24086  Approved            A1CF
# 3          HGNC:7  Approved             A2M
# 4      HGNC:27057  Approved         A2M-AS1
# ...           ...       ...             ...
# 45474  HGNC:25820  Approved          ZYG11B
# 45475  HGNC:13200  Approved             ZYX
# 45476  HGNC:51695  Approved           ZYXP1
# 45477  HGNC:29027  Approved           ZZEF1
# 45478  HGNC:24523  Approved            ZZZ3
#
#                                            Approved name  Ensembl gene ID  \
# 0                                 alpha-1-B glycoprotein  ENSG00000121410
# 1                                   A1BG antisense RNA 1  ENSG00000268895
# 2                         APOBEC1 complementation factor  ENSG00000148584
# 3                                  alpha-2-macroglobulin  ENSG00000175899
# 4                                    A2M antisense RNA 1  ENSG00000245105
# ...                                                  ...              ...
# 45474       zyg-11 family member B, cell cycle regulator  ENSG00000162378
# 45475                                              zyxin  ENSG00000159840
# 45476                                 zyxin pseudogene 1  ENSG00000274572
# 45477  zinc finger ZZ-type and EF-hand domain contain...  ENSG00000074755
# 45478                   zinc finger ZZ-type containing 3  ENSG00000036549
#
#       NCBI gene ID UCSC gene ID RefSeq accession
# 0                1   uc002qsd.5        NM_130786
# 1           503538   uc002qse.3        NR_015380
# 2            29974   uc057tgv.1        NM_014576
# 3                2   uc001qvk.2        NM_000014
# 4           144571   uc009zgj.2        NR_026971
# ...            ...          ...              ...
# 45474        79699   uc001cuj.4        NM_024646
# 45475         7791   uc003wcx.5        NM_003461
# 45476    106480342          NaN        NG_044600
# 45477        23140   uc002fxe.4        NM_015113
# 45478        26009   uc001dhq.4        NM_015534
#
# [45479 rows x 8 columns]

# %%
annotation_matrix=pd.merge(df_mine, result_3, on='Ensembl gene ID', how='left')

# %%
annotation_matrix
# Out:
#        Ensembl gene ID     HGNC ID    Status Approved symbol  \
# 0      ENSG00000198900  HGNC:11986  Approved            TOP1
# 1      ENSG00000215515   HGNC:5408  Approved         IFIT1P1
# 2      ENSG00000215399  HGNC:39299  Approved         HMGB3P7
# 3      ENSG00000196331         NaN       NaN             NaN
# 4      ENSG00000206044         NaN       NaN             NaN
# ...                ...         ...       ...             ...
# 34654  ENSG00000187210   HGNC:4203  Approved           GCNT1
# 34655  ENSG00000263426  HGNC:46487  Approved       RN7SL471P
# 34656  ENSG00000264729         NaN       NaN             NaN
# 34657  ENSG00000263919         NaN       NaN             NaN
# 34658  ENSG00000173894   HGNC:1552  Approved            CBX2
#
#                                            Approved name NCBI gene ID  \
# 0                                    DNA topoisomerase I         7150
# 1      interferon induced protein with tetratricopept...         8373
# 2                 high mobility group box 3 pseudogene 7    100420033
# 3                                                    NaN          NaN
# 4                                                    NaN          NaN
# ...                                                  ...          ...
# 34654              glucosaminyl (N-acetyl) transferase 1         2650
# 34655              RNA, 7SL, cytoplasmic 471, pseudogene    106481051
# 34656                                                NaN          NaN
# 34657                                                NaN          NaN
# 34658                                        chromobox 2        84733
#
#       UCSC gene ID RefSeq accession
# 0       uc002xjl.4        NM_003286
# 1              NaN        NG_001215
# 2              NaN        NG_024948
# 3              NaN              NaN
# 4              NaN              NaN
# ...            ...              ...
# 34654   uc010mpg.4     NM_001097634
# 34655   uc063mmi.1        NG_044132
# 34656          NaN              NaN
# 34657          NaN              NaN
# 34658   uc002jxc.4        NM_032647
#
# [34659 rows x 8 columns]

# %%
annotation_matrix.to_csv("annotation_matrix.txt")
