# %%
# In case you do not have following packages installed, uncomment instalisation.

import pandas as pd
import numpy as np
import os
import glob
import functools
from pathlib import Path
import matplotlib.pyplot as plt

#!pip install dask[complete];
# you need to run these in case dask gives you error, it might need update.
#!pip install --upgrade pandas "dask[complete]"
#python -m pip install "dask[dataframe]" --upgrade
#import dask.dataframe as dd

from sklearn.model_selection import train_test_split

from sklearn.metrics import precision_score, recall_score, f1_score, roc_curve, accuracy_score
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_recall_curve

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import StratifiedKFold
from sklearn.inspection import permutation_importance       

from sklearn.feature_selection import SelectFromModel
from sklearn.utils import class_weight

#!pip3 install xgboost
#from xgboost import XGBClassifier

#!pip install conorm
#import conorm # for tmm normalisation

#!pip3 install pydeseq2 or pip install pydeseq2
#from pydeseq2.dds import DeseqDataSet
#from pydeseq2.ds import DeseqStats
#from pydeseq2.utils import load_example_data



#to install R :
#conda install -c r r-irkernel

#to install a library from R
#!pip install library edgeR
# pip install rpy2

# %% [markdown]
# ### Data for Imaging of Parkinson ###

# %%
path3 = Path("/home/znazari/data/open_proteomic/")
path2 = Path("/home/znazari/data/")

# %%
# %%capture
pathway = pd.read_csv(path2/"Reactome_official_11dic2023_hsa.txt",delimiter='\t',error_bad_lines=True, header=None, low_memory=False)
pathway = pathway.set_index(pathway.columns[0])
pathway

# %%
# %%capture
# Count non-NaN values in each row
row_counts = pathway.count(axis=1)

# Add a new column 'non_nan_count' to the DataFrame
pathway['non_nan_count'] = row_counts

# Sort the DataFrame based on the 'non_nan_count' column in descending order
sorted_pathway = pathway.sort_values(by='non_nan_count', ascending=False)

# Drop the temporary 'non_nan_count' column
sorted_pathway = sorted_pathway.drop(columns='non_nan_count')

# Display the sorted DataFrame
sorted_pathway

# %%
# Assuming 'sorted_pathway' is your DataFrame

# Count non-NaN values in each row
row_counts = sorted_pathway.count(axis=1)

# Add a new column 'non_nan_count' to the DataFrame
sorted_pathway['non_nan_count'] = row_counts

# Exclude rows with less than 10 non-NaN values
filtered_pathway = sorted_pathway[sorted_pathway['non_nan_count'] >= 10]

# Drop the temporary 'non_nan_count' column
filtered_pathway = filtered_pathway.drop(columns='non_nan_count')

# Display the filtered DataFrame
filtered_pathway
# Out:
#                                                         1         2     \
# 0
# R-HSA-162582___Signal Transduction                      AAAS      AAMP
# R-HSA-168256___Immune System                              1C         8
# R-HSA-1430728___Metabolism                          18S rRNA  28S rRNA
# R-HSA-1643685___Disease                             18S rRNA        1a
# R-HSA-392499___Metabolism of proteins               18S rRNA  28S rRNA
# ...                                                      ...       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis      B3GALNT1  B4GALNT1
# R-HSA-1250342___PI3K events in ERBB4 signaling           BTC     ERBB4
# R-HSA-203615___eNOS activation                          AKT1     CALM1
# R-HSA-451306___Ionotropic activity of kainate r...     CALM1      DLG1
# R-HSA-418889___Caspase activation via Dependenc...     APPL1     CASP3
#
#                                                          3        4     \
# 0
# R-HSA-162582___Signal Transduction                       AATF    ABCA1
# R-HSA-168256___Immune System                               9b     A1BG
# R-HSA-1430728___Metabolism                          5.8S rRNA  5S rRNA
# R-HSA-1643685___Disease                              28S rRNA       3a
# R-HSA-392499___Metabolism of proteins               5.8S rRNA  5S rRNA
# ...                                                       ...      ...
# R-HSA-9840309___Glycosphingolipid biosynthesis           CERK     CPTP
# R-HSA-1250342___PI3K events in ERBB4 signaling           EREG    HBEGF
# R-HSA-203615___eNOS activation                           CAV1     CYGB
# R-HSA-451306___Ionotropic activity of kainate r...       DLG3     DLG4
# R-HSA-418889___Caspase activation via Dependenc...      CASP9    DAPK1
#
#                                                                          5     \
# 0
# R-HSA-162582___Signal Transduction                                      ABCD3
# R-HSA-168256___Immune System                                             AAAS
# R-HSA-1430728___Metabolism                                               AAAS
# R-HSA-1643685___Disease                                                    3b
# R-HSA-392499___Metabolism of proteins               7SL RNA (ENSG00000222619)
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                          ESYT1
# R-HSA-1250342___PI3K events in ERBB4 signaling                           NRG1
# R-HSA-203615___eNOS activation                                          DDAH1
# R-HSA-451306___Ionotropic activity of kainate r...                      GRIK1
# R-HSA-418889___Caspase activation via Dependenc...                      DAPK2
#
#                                                                          6     \
# 0
# R-HSA-162582___Signal Transduction                                      ABCG1
# R-HSA-168256___Immune System                                             AAMP
# R-HSA-1430728___Metabolism                                               AACS
# R-HSA-1643685___Disease                                             5.8S rRNA
# R-HSA-392499___Metabolism of proteins               7SL RNA (ENSG00000222639)
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                          ESYT2
# R-HSA-1250342___PI3K events in ERBB4 signaling                           NRG2
# R-HSA-203615___eNOS activation                                       HSP90AA1
# R-HSA-451306___Ionotropic activity of kainate r...                      GRIK2
# R-HSA-418889___Caspase activation via Dependenc...                      DAPK3
#
#                                                        7       8     \
# 0
# R-HSA-162582___Signal Transduction                    ABCG5   ABCG8
# R-HSA-168256___Immune System                         ABCA13   ABCE1
# R-HSA-1430728___Metabolism                            AADAC   AADAT
# R-HSA-1643685___Disease                             5S rRNA       6
# R-HSA-392499___Metabolism of proteins                 A4GNT    AAAS
# ...                                                     ...     ...
# R-HSA-9840309___Glycosphingolipid biosynthesis        ESYT3    GLTP
# R-HSA-1250342___PI3K events in ERBB4 signaling         NRG3    NRG4
# R-HSA-203615___eNOS activation                       LYPLA1    NOS3
# R-HSA-451306___Ionotropic activity of kainate r...    GRIK3   GRIK4
# R-HSA-418889___Caspase activation via Dependenc...      DCC  MAGED1
#
#                                                                          9     \
# 0
# R-HSA-162582___Signal Transduction                                     ABHD12
# R-HSA-168256___Immune System                                             ABI1
# R-HSA-1430728___Metabolism                                              AANAT
# R-HSA-1643685___Disease                             7SL RNA (ENSG00000222619)
# R-HSA-392499___Metabolism of proteins                                   AARS1
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                           UGCG
# R-HSA-1250342___PI3K events in ERBB4 signaling                         PIK3CA
# R-HSA-203615___eNOS activation                                            SPR
# R-HSA-451306___Ionotropic activity of kainate r...                      GRIK5
# R-HSA-418889___Caspase activation via Dependenc...                      UNC5A
#
#                                                                          10    \
# 0
# R-HSA-162582___Signal Transduction                                    ABHD17A
# R-HSA-168256___Immune System                                             ABI2
# R-HSA-1430728___Metabolism                                           AASDHPPT
# R-HSA-1643685___Disease                             7SL RNA (ENSG00000222639)
# R-HSA-392499___Metabolism of proteins                                   AARS2
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                           UGT8
# R-HSA-1250342___PI3K events in ERBB4 signaling                         PIK3R1
# R-HSA-203615___eNOS activation                                        ZDHHC21
# R-HSA-451306___Ionotropic activity of kainate r...                      NCALD
# R-HSA-418889___Caspase activation via Dependenc...                      UNC5B
#
#                                                     ...    2598     2599  \
# 0                                                   ...
# R-HSA-162582___Signal Transduction                  ...  ZDHHC9  ZFYVE16
# R-HSA-168256___Immune System                        ...     NaN      NaN
# R-HSA-1430728___Metabolism                          ...     NaN      NaN
# R-HSA-1643685___Disease                             ...     NaN      NaN
# R-HSA-392499___Metabolism of proteins               ...     NaN      NaN
# ...                                                 ...     ...      ...
# R-HSA-9840309___Glycosphingolipid biosynthesis      ...     NaN      NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling      ...     NaN      NaN
# R-HSA-203615___eNOS activation                      ...     NaN      NaN
# R-HSA-451306___Ionotropic activity of kainate r...  ...     NaN      NaN
# R-HSA-418889___Caspase activation via Dependenc...  ...     NaN      NaN
#
#                                                       2600    2601     2602  \
# 0
# R-HSA-162582___Signal Transduction                  ZFYVE9  ZNF217  ZNF512B
# R-HSA-168256___Immune System                           NaN     NaN      NaN
# R-HSA-1430728___Metabolism                             NaN     NaN      NaN
# R-HSA-1643685___Disease                                NaN     NaN      NaN
# R-HSA-392499___Metabolism of proteins                  NaN     NaN      NaN
# ...                                                    ...     ...      ...
# R-HSA-9840309___Glycosphingolipid biosynthesis         NaN     NaN      NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling         NaN     NaN      NaN
# R-HSA-203615___eNOS activation                         NaN     NaN      NaN
# R-HSA-451306___Ionotropic activity of kainate r...     NaN     NaN      NaN
# R-HSA-418889___Caspase activation via Dependenc...     NaN     NaN      NaN
#
#                                                      2603    2604  2605  \
# 0
# R-HSA-162582___Signal Transduction                  ZNRF3  ZRANB1  ZW10
# R-HSA-168256___Immune System                          NaN     NaN   NaN
# R-HSA-1430728___Metabolism                            NaN     NaN   NaN
# R-HSA-1643685___Disease                               NaN     NaN   NaN
# R-HSA-392499___Metabolism of proteins                 NaN     NaN   NaN
# ...                                                   ...     ...   ...
# R-HSA-9840309___Glycosphingolipid biosynthesis        NaN     NaN   NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling        NaN     NaN   NaN
# R-HSA-203615___eNOS activation                        NaN     NaN   NaN
# R-HSA-451306___Ionotropic activity of kainate r...    NaN     NaN   NaN
# R-HSA-418889___Caspase activation via Dependenc...    NaN     NaN   NaN
#
#                                                       2606   2607
# 0
# R-HSA-162582___Signal Transduction                  ZWILCH  ZWINT
# R-HSA-168256___Immune System                           NaN    NaN
# R-HSA-1430728___Metabolism                             NaN    NaN
# R-HSA-1643685___Disease                                NaN    NaN
# R-HSA-392499___Metabolism of proteins                  NaN    NaN
# ...                                                    ...    ...
# R-HSA-9840309___Glycosphingolipid biosynthesis         NaN    NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling         NaN    NaN
# R-HSA-203615___eNOS activation                         NaN    NaN
# R-HSA-451306___Ionotropic activity of kainate r...     NaN    NaN
# R-HSA-418889___Caspase activation via Dependenc...     NaN    NaN
#
# [1650 rows x 2607 columns]

# %%
# Value to check for existence
value_to_check = 'rRNA'

# Check if the value exists in the specified column
if value_to_check in gin["Gene name"].values:
    print(f'The value {value_to_check} exists in Column2.')
else:
    print(f'The value {value_to_check} does not exist in Column2.')
# Out:
# The value rRNA does not exist in Column2.

# %%
ensemble = pd.read_csv(path3/'Ensemble_GeneID_TranscriptID_Symbol_mart_export.txt',delimiter='\t')
gin = ensemble[['Gene name','Gene stable ID']]
#droping the NaN value rows:
gin2 = gin.dropna(subset=['Gene name'])
gin2
# Out:
#        Gene name   Gene stable ID
# 0          MT-TF  ENSG00000210049
# 1        MT-RNR1  ENSG00000211459
# 2          MT-TV  ENSG00000210077
# 3        MT-RNR2  ENSG00000210082
# 4         MT-TL1  ENSG00000209082
# ...          ...              ...
# 274608    SPATA1  ENSG00000122432
# 274609    SPATA1  ENSG00000122432
# 274610    SPATA1  ENSG00000122432
# 274611    SPATA1  ENSG00000122432
# 274612    SPATA1  ENSG00000122432
#
# [240493 rows x 2 columns]

# %%
# Create a dictionary mapping gene names to gene stable IDs from 'gin2'
gene_mapping = dict(zip(gin2['Gene name'], gin2['Gene stable ID']))

# Replace gene names with gene stable IDs in 'filtered_pathway'
filtered_pathway.replace({'Gene name': gene_mapping}, inplace=True)

# %%
filtered_pathway
# Out:
#                                                         1         2     \
# 0
# R-HSA-162582___Signal Transduction                      AAAS      AAMP
# R-HSA-168256___Immune System                              1C         8
# R-HSA-1430728___Metabolism                          18S rRNA  28S rRNA
# R-HSA-1643685___Disease                             18S rRNA        1a
# R-HSA-392499___Metabolism of proteins               18S rRNA  28S rRNA
# ...                                                      ...       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis      B3GALNT1  B4GALNT1
# R-HSA-1250342___PI3K events in ERBB4 signaling           BTC     ERBB4
# R-HSA-203615___eNOS activation                          AKT1     CALM1
# R-HSA-451306___Ionotropic activity of kainate r...     CALM1      DLG1
# R-HSA-418889___Caspase activation via Dependenc...     APPL1     CASP3
#
#                                                          3        4     \
# 0
# R-HSA-162582___Signal Transduction                       AATF    ABCA1
# R-HSA-168256___Immune System                               9b     A1BG
# R-HSA-1430728___Metabolism                          5.8S rRNA  5S rRNA
# R-HSA-1643685___Disease                              28S rRNA       3a
# R-HSA-392499___Metabolism of proteins               5.8S rRNA  5S rRNA
# ...                                                       ...      ...
# R-HSA-9840309___Glycosphingolipid biosynthesis           CERK     CPTP
# R-HSA-1250342___PI3K events in ERBB4 signaling           EREG    HBEGF
# R-HSA-203615___eNOS activation                           CAV1     CYGB
# R-HSA-451306___Ionotropic activity of kainate r...       DLG3     DLG4
# R-HSA-418889___Caspase activation via Dependenc...      CASP9    DAPK1
#
#                                                                          5     \
# 0
# R-HSA-162582___Signal Transduction                                      ABCD3
# R-HSA-168256___Immune System                                             AAAS
# R-HSA-1430728___Metabolism                                               AAAS
# R-HSA-1643685___Disease                                                    3b
# R-HSA-392499___Metabolism of proteins               7SL RNA (ENSG00000222619)
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                          ESYT1
# R-HSA-1250342___PI3K events in ERBB4 signaling                           NRG1
# R-HSA-203615___eNOS activation                                          DDAH1
# R-HSA-451306___Ionotropic activity of kainate r...                      GRIK1
# R-HSA-418889___Caspase activation via Dependenc...                      DAPK2
#
#                                                                          6     \
# 0
# R-HSA-162582___Signal Transduction                                      ABCG1
# R-HSA-168256___Immune System                                             AAMP
# R-HSA-1430728___Metabolism                                               AACS
# R-HSA-1643685___Disease                                             5.8S rRNA
# R-HSA-392499___Metabolism of proteins               7SL RNA (ENSG00000222639)
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                          ESYT2
# R-HSA-1250342___PI3K events in ERBB4 signaling                           NRG2
# R-HSA-203615___eNOS activation                                       HSP90AA1
# R-HSA-451306___Ionotropic activity of kainate r...                      GRIK2
# R-HSA-418889___Caspase activation via Dependenc...                      DAPK3
#
#                                                        7       8     \
# 0
# R-HSA-162582___Signal Transduction                    ABCG5   ABCG8
# R-HSA-168256___Immune System                         ABCA13   ABCE1
# R-HSA-1430728___Metabolism                            AADAC   AADAT
# R-HSA-1643685___Disease                             5S rRNA       6
# R-HSA-392499___Metabolism of proteins                 A4GNT    AAAS
# ...                                                     ...     ...
# R-HSA-9840309___Glycosphingolipid biosynthesis        ESYT3    GLTP
# R-HSA-1250342___PI3K events in ERBB4 signaling         NRG3    NRG4
# R-HSA-203615___eNOS activation                       LYPLA1    NOS3
# R-HSA-451306___Ionotropic activity of kainate r...    GRIK3   GRIK4
# R-HSA-418889___Caspase activation via Dependenc...      DCC  MAGED1
#
#                                                                          9     \
# 0
# R-HSA-162582___Signal Transduction                                     ABHD12
# R-HSA-168256___Immune System                                             ABI1
# R-HSA-1430728___Metabolism                                              AANAT
# R-HSA-1643685___Disease                             7SL RNA (ENSG00000222619)
# R-HSA-392499___Metabolism of proteins                                   AARS1
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                           UGCG
# R-HSA-1250342___PI3K events in ERBB4 signaling                         PIK3CA
# R-HSA-203615___eNOS activation                                            SPR
# R-HSA-451306___Ionotropic activity of kainate r...                      GRIK5
# R-HSA-418889___Caspase activation via Dependenc...                      UNC5A
#
#                                                                          10    \
# 0
# R-HSA-162582___Signal Transduction                                    ABHD17A
# R-HSA-168256___Immune System                                             ABI2
# R-HSA-1430728___Metabolism                                           AASDHPPT
# R-HSA-1643685___Disease                             7SL RNA (ENSG00000222639)
# R-HSA-392499___Metabolism of proteins                                   AARS2
# ...                                                                       ...
# R-HSA-9840309___Glycosphingolipid biosynthesis                           UGT8
# R-HSA-1250342___PI3K events in ERBB4 signaling                         PIK3R1
# R-HSA-203615___eNOS activation                                        ZDHHC21
# R-HSA-451306___Ionotropic activity of kainate r...                      NCALD
# R-HSA-418889___Caspase activation via Dependenc...                      UNC5B
#
#                                                     ...    2598     2599  \
# 0                                                   ...
# R-HSA-162582___Signal Transduction                  ...  ZDHHC9  ZFYVE16
# R-HSA-168256___Immune System                        ...     NaN      NaN
# R-HSA-1430728___Metabolism                          ...     NaN      NaN
# R-HSA-1643685___Disease                             ...     NaN      NaN
# R-HSA-392499___Metabolism of proteins               ...     NaN      NaN
# ...                                                 ...     ...      ...
# R-HSA-9840309___Glycosphingolipid biosynthesis      ...     NaN      NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling      ...     NaN      NaN
# R-HSA-203615___eNOS activation                      ...     NaN      NaN
# R-HSA-451306___Ionotropic activity of kainate r...  ...     NaN      NaN
# R-HSA-418889___Caspase activation via Dependenc...  ...     NaN      NaN
#
#                                                       2600    2601     2602  \
# 0
# R-HSA-162582___Signal Transduction                  ZFYVE9  ZNF217  ZNF512B
# R-HSA-168256___Immune System                           NaN     NaN      NaN
# R-HSA-1430728___Metabolism                             NaN     NaN      NaN
# R-HSA-1643685___Disease                                NaN     NaN      NaN
# R-HSA-392499___Metabolism of proteins                  NaN     NaN      NaN
# ...                                                    ...     ...      ...
# R-HSA-9840309___Glycosphingolipid biosynthesis         NaN     NaN      NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling         NaN     NaN      NaN
# R-HSA-203615___eNOS activation                         NaN     NaN      NaN
# R-HSA-451306___Ionotropic activity of kainate r...     NaN     NaN      NaN
# R-HSA-418889___Caspase activation via Dependenc...     NaN     NaN      NaN
#
#                                                      2603    2604  2605  \
# 0
# R-HSA-162582___Signal Transduction                  ZNRF3  ZRANB1  ZW10
# R-HSA-168256___Immune System                          NaN     NaN   NaN
# R-HSA-1430728___Metabolism                            NaN     NaN   NaN
# R-HSA-1643685___Disease                               NaN     NaN   NaN
# R-HSA-392499___Metabolism of proteins                 NaN     NaN   NaN
# ...                                                   ...     ...   ...
# R-HSA-9840309___Glycosphingolipid biosynthesis        NaN     NaN   NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling        NaN     NaN   NaN
# R-HSA-203615___eNOS activation                        NaN     NaN   NaN
# R-HSA-451306___Ionotropic activity of kainate r...    NaN     NaN   NaN
# R-HSA-418889___Caspase activation via Dependenc...    NaN     NaN   NaN
#
#                                                       2606   2607
# 0
# R-HSA-162582___Signal Transduction                  ZWILCH  ZWINT
# R-HSA-168256___Immune System                           NaN    NaN
# R-HSA-1430728___Metabolism                             NaN    NaN
# R-HSA-1643685___Disease                                NaN    NaN
# R-HSA-392499___Metabolism of proteins                  NaN    NaN
# ...                                                    ...    ...
# R-HSA-9840309___Glycosphingolipid biosynthesis         NaN    NaN
# R-HSA-1250342___PI3K events in ERBB4 signaling         NaN    NaN
# R-HSA-203615___eNOS activation                         NaN    NaN
# R-HSA-451306___Ionotropic activity of kainate r...     NaN    NaN
# R-HSA-418889___Caspase activation via Dependenc...     NaN    NaN
#
# [1650 rows x 2607 columns]

# %%
# Loading the already preprocessed data:

path2 = Path("/home/znazari/data") # where the output data will be saved at the end.

# with all the filtered genes:

ir3_rna_step_vst =  pd.read_csv(path2/'mydata_Log_CPM_filtered_bact_sex_effect_removed_RIN_covariate.txt',delimiter='\t' )

diagnosis = pd.read_csv(path2/'patients_HC_PK_diagnosis.csv')

# mapping diagnosis to zero and one.
diagnosis['COHORT_DEFINITION'] = diagnosis['COHORT_DEFINITION'].map({'Healthy Control': 0, "Parkinson's Disease": 1})

# X: feature matrix, y: the target variable

X=ir3_rna_step_vst.T
y=diagnosis['COHORT_DEFINITION']

# %%
ir3_rna_step_vst
# Out:
#                      3000      3001      3002      3003      3004      3006  \
# ENSG00000000419  3.845119  5.213262  4.837730  5.101270  4.974751  4.825708
# ENSG00000000457  5.648852  6.202708  5.624314  6.067816  6.092646  6.223112
# ENSG00000000460  3.817007  4.095830  4.012751  4.262379  3.969580  4.374808
# ENSG00000000938  8.463275  8.810743  8.368607  8.466923  8.927912  9.043402
# ENSG00000000971  1.944928  3.384911  2.522713  4.085667  3.693875  2.544924
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000285219  2.721748  1.638440  3.771521  1.812421  2.549122  2.058582
# ENSG00000285230  2.322872  2.517009  2.599599  2.386956  2.851771  2.737816
# ENSG00000285280  4.541140  1.709681  2.196385  2.727775  2.760335  2.204436
# ENSG00000285399  5.099339  5.353763  4.708896  5.048748  5.349433  5.567314
# ENSG00000285410  5.241609  6.019862  5.414418  5.555605  5.554071  5.654699
#
#                      3007      3008      3009      3010  ...      4121  \
# ENSG00000000419  5.011214  5.229956  5.174531  5.284571  ...  4.451699
# ENSG00000000457  6.003440  6.010872  6.272480  6.285266  ...  5.863215
# ENSG00000000460  4.417553  4.331596  4.675491  4.348990  ...  3.957820
# ENSG00000000938  8.681277  8.235545  8.067889  8.631065  ...  8.416943
# ENSG00000000971  3.968554  4.085922  4.811027  4.093739  ...  2.209538
# ...                   ...       ...       ...       ...  ...       ...
# ENSG00000285219  2.125234  1.765596  2.069582  1.764143  ...  2.495753
# ENSG00000285230  2.894924  2.388526  2.458358  2.695723  ...  2.169890
# ENSG00000285280  2.655007  2.044956  1.865374  1.846651  ...  2.344181
# ENSG00000285399  5.192088  5.066864  5.211345  5.326240  ...  5.208116
# ENSG00000285410  5.836791  5.971206  6.017686  6.123887  ...  5.526208
#
#                      4122      4123      4124      4125      4126      4135  \
# ENSG00000000419  5.408345  5.247058  4.584573  4.398598  5.449524  5.015613
# ENSG00000000457  6.422896  6.368654  6.114092  5.798945  6.383039  6.290690
# ENSG00000000460  4.518421  4.424952  4.145217  4.194468  4.628795  4.747158
# ENSG00000000938  9.104202  8.838484  9.193292  8.217039  8.772340  8.497247
# ENSG00000000971  2.390307  3.974330  2.196031  2.196303  3.910535  4.403068
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000285219  1.830501  1.218611  2.165035  3.126425  1.943526  0.648852
# ENSG00000285230  2.481177  2.779666  2.643108  2.415556  2.438769  2.464313
# ENSG00000285280  2.573584  2.253876  2.459218  3.058924  2.916741  2.501802
# ENSG00000285399  5.197208  5.421681  5.656614  5.370812  5.384910  5.832674
# ENSG00000285410  6.105318  5.998763  5.768046  5.472123  5.950408  5.878510
#
#                      4136      4139     41410
# ENSG00000000419  3.987076  5.496642  4.963686
# ENSG00000000457  5.179048  6.293745  6.058590
# ENSG00000000460  3.569694  4.025577  4.268701
# ENSG00000000938  8.612951  8.695999  8.676493
# ENSG00000000971  2.359305  2.445675  3.267041
# ...                   ...       ...       ...
# ENSG00000285219  2.959793  2.179546  2.136740
# ENSG00000285230  2.474065  2.487454  2.544368
# ENSG00000285280  2.977444  2.196541  2.727432
# ENSG00000285399  4.774830  4.800063  5.287198
# ENSG00000285410  5.187680  5.677015  5.755279
#
# [13104 rows x 583 columns]

# %%
filtered_df = ir3_rna_step_vst[ir3_rna_step_vst.index.isin(unique_ensg['Gene stable ID'])]

# %%
filtered_df
# Out:
#                      3000      3001      3002      3003      3004      3006  \
# ENSG00000000938  8.463275  8.810743  8.368607  8.466923  8.927912  9.043402
# ENSG00000000971  1.944928  3.384911  2.522713  4.085667  3.693875  2.544924
# ENSG00000002330  3.571424  3.959793  3.388754  4.085483  3.756835  3.986339
# ENSG00000002549  5.872790  5.908892  6.004722  6.073372  5.541370  7.682882
# ENSG00000002587  0.139701  1.312890  1.736479  0.976318  1.218935  0.709119
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000271303  4.141592  5.154501  3.158052  5.093705  3.283577  5.812244
# ENSG00000271605  3.253041  3.349505  4.194189  4.647757  3.770106  4.032242
# ENSG00000272325  6.689842  6.335426  6.208001  6.495175  6.384606  6.810942
# ENSG00000272886  5.031533  5.461262  4.897880  5.414562  5.042777  5.492468
# ENSG00000277586  0.955260  1.599759  2.141387  1.039230  0.930909  2.080828
#
#                      3007      3008      3009      3010  ...      4121  \
# ENSG00000000938  8.681277  8.235545  8.067889  8.631065  ...  8.416943
# ENSG00000000971  3.968554  4.085922  4.811027  4.093739  ...  2.209538
# ENSG00000002330  3.665170  3.716128  4.060661  4.147625  ...  3.368043
# ENSG00000002549  5.899073  5.657070  6.353882  5.949753  ...  6.898440
# ENSG00000002587  1.053174  1.422313  2.073881  1.777967  ...  1.751712
# ...                   ...       ...       ...       ...  ...       ...
# ENSG00000271303  4.497693  4.390843  3.943871  4.750242  ...  2.731588
# ENSG00000271605  3.725165  4.014289  3.882068  3.648119  ...  4.301260
# ENSG00000272325  6.646111  6.402878  6.308627  6.737337  ...  6.560920
# ENSG00000272886  5.444711  5.371691  5.520976  5.315246  ...  5.277152
# ENSG00000277586  1.299974  2.903225  1.291601  1.154745  ...  1.670995
#
#                      4122      4123      4124      4125      4126      4135  \
# ENSG00000000938  9.104202  8.838484  9.193292  8.217039  8.772340  8.497247
# ENSG00000000971  2.390307  3.974330  2.196031  2.196303  3.910535  4.403068
# ENSG00000002330  4.429167  3.945994  4.056662  2.965991  4.581369  4.673969
# ENSG00000002549  6.502385  6.639824  5.425128  5.561972  6.668685  7.166978
# ENSG00000002587  0.780928  1.562588  0.983353  1.199543  0.721738 -0.725075
# ...                   ...       ...       ...       ...       ...       ...
# ENSG00000271303  4.644567  4.741196  4.482349  3.986768  5.829626  5.499389
# ENSG00000271605  3.829374  4.916163  4.849648  3.918818  3.755242  4.052355
# ENSG00000272325  6.703202  6.730188  6.621639  6.583015  6.837237  6.500973
# ENSG00000272886  5.400093  5.523296  5.426866  5.269029  5.388664  5.499137
# ENSG00000277586  1.502712  2.105388  1.939682  1.180061  1.596707  1.029237
#
#                      4136      4139     41410
# ENSG00000000938  8.612951  8.695999  8.676493
# ENSG00000000971  2.359305  2.445675  3.267041
# ENSG00000002330  3.146942  4.272373  3.885313
# ENSG00000002549  6.111543  6.510586  6.325302
# ENSG00000002587  1.494510  1.673137  0.951384
# ...                   ...       ...       ...
# ENSG00000271303  3.893179  5.252354  4.670282
# ENSG00000271605  3.537703  4.062805  3.979138
# ENSG00000272325  6.102476  6.663363  6.564332
# ENSG00000272886  4.822674  5.094705  5.293258
# ENSG00000277586  0.550024  2.121583  1.401408
#
# [2212 rows x 583 columns]

# %%
X=filtered_df.T
y=diagnosis['COHORT_DEFINITION']

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

#  Initialize and train the XGBoost model
xgb_model = XGBClassifier()
xgb_model.fit(X_train, y_train)

#  Make predictions on the testing set
y_pred_proba = xgb_model.predict_proba(X_test)[:, 1]

# Calculate AU-ROC score
au_roc_score = roc_auc_score(y_test, y_pred_proba)

# Print the AU-ROC score
print(f'AU-ROC Score: {au_roc_score}')
# Out:
# AU-ROC Score: 0.565281461833186

# %%
# Sample DataFrames
df1 = pd.DataFrame({'Column1': [1, 2, 3, 4, 5], 'Data1': ['A', 'B', 'C', 'D', 'E']})

df2 = pd.DataFrame({'Column2': [3, 4, 5, 6, 7], 'Data2': ['X', 'Y', 'Z', 'W', 'K']})

# Using merge to find the intersection
intersection = pd.merge(df1, df2, left_on='Column1', right_on='Column2', how='inner')

print(intersection)
# Out:
#    Column1 Data1  Column2 Data2
# 0        3     C        3     X
# 1        4     D        4     Y
# 2        5     E        5     Z

# %% [markdown]
# # compare between merge and isin:
# in the merge we actually want to have the data from the both pandas dataframe files but when we use isin
# we basiccaclly want from one dataframe those that are in common with the other one.

# %%
df1
# Out:
#    Column1 Data1
# 0        1     A
# 1        2     B
# 2        3     C
# 3        4     D
# 4        5     E

# %%
df2
# Out:
#    Column2 Data2
# 0        3     X
# 1        4     Y
# 2        5     Z
# 3        6     W
# 4        7     K

# %% [raw]
# intersection

# %%
common_values2 = df1[df1['Column1'].isin(df2['Column2'])]

# %%
common_values2
# Out:
#    Column1 Data1
# 2        3     C
# 3        4     D
# 4        5     E

# %%
pd.set_option('display.max_rows', None)

# %%
pd.reset_option('display.max_rows')
